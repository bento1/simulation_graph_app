# %%
import torch
import torch.nn.functional as F
from fem_dataset_to_image_full_mesh_diffusion import FemImageDataset as MeshDataset
from fem_model import ScalingVAE3
import json
from torch.utils.data import DataLoader
from utils import EarlyStopping
import gc
import numpy as np
import matplotlib.pyplot as plt


early_stopping = EarlyStopping(
    patience=10,     # FEM/GNN은 15~30 권장
    min_delta=1e-6,  # loss 스케일에 맞게
    mode="min"
)
def collate_flatten(batch): 
    images, conds = [], [] 
    batch_size=len(batch) 
    step_num_in_batch=len(batch[0]["image"]) 
    idxs=[] 
    for i in range(batch_size): 
        idx = torch.randperm(len(batch[0]["image"])) 
        idxs.append(idx) 
        # print(batch[i]['min_max'])
    idxs=np.array(idxs).T 

    for i in range(step_num_in_batch): 
        batch_images=[] 
        batch_conds=[] 
        for b_i,b in enumerate(batch): 
            id=idxs[i][b_i] 
            batch_images.append(b['image'][id]) 
            batch_conds.append(b['cond'][id]) 
        images.append(batch_images) 
        conds.append(batch_conds) 
    return { "image": images, "cond": conds, }

def draw(data1,data2,model_param): 
    stride=1 
    clip_q=(0.25,0.75) 
    cmap="jet" 
    ql, qh = np.quantile(data1.cpu().detach().numpy(), clip_q) 
    Uf1_clip = np.clip(data1.cpu().detach().numpy(), ql, qh) 
    ql, qh = np.quantile(data2.cpu().detach().numpy(), clip_q) 
    Uf2_clip = np.clip(data2.cpu().detach().numpy(), ql, qh) 
    print('vmin',Uf1_clip.min(),'vmax',Uf1_clip.max())
    plt.figure(figsize=(8, 4)) 
    plt.subplot(1, 3, 1) 
    plt.imshow(Uf1_clip, cmap="gray",vmin=Uf1_clip.min(),vmax=Uf1_clip.max()) 
    plt.title("Image 1") 
    plt.axis("off") 
    plt.subplot(1, 3, 2) 
    plt.imshow(Uf2_clip, cmap="gray",vmin=Uf1_clip.min(),vmax=Uf1_clip.max())
    plt.title("Image 2") 
    plt.axis("off") 
    plt.subplot(1, 3, 3) 
    plt.imshow(np.abs(Uf1_clip-Uf2_clip), cmap="gray",vmin=Uf1_clip.min(),vmax=Uf1_clip.max())
    plt.title("Image 3") 
    plt.axis("off")
    plt.tight_layout() 
    plt.show()

def kl_divergence_gaussian(mu, logvar, clamp=(-0.3, 0.3)):
    """
    KL( N(mu, var) || N(0, I) )
    Supports mu/logvar with shape:
      [B, Z] or [B, C, H, W] or [B, ...]
    """
    if clamp is not None:
        logvar = torch.clamp(logvar, min=clamp[0], max=clamp[1])

    # flatten all non-batch dimensions
    mu = mu.view(mu.size(0), -1)
    logvar = logvar.view(logvar.size(0), -1)

    kl = 0.5 * torch.sum(
        torch.exp(logvar) + mu**2 - 1.0 - logvar,
        dim=1
    )

    return kl.mean()

def charbonnier_loss(pred: torch.Tensor,
                     target: torch.Tensor,
                     eps: float = 1e-8,
                     reduction: str = "mean") -> torch.Tensor:
    """
    Charbonnier loss (a smooth L1 / pseudo-Huber variant):
        L = sqrt((pred - target)^2 + eps^2)

    Args:
        pred, target: same shape tensors
        eps: smoothing term (bigger -> more L1-like near 0)
        reduction: "mean" | "sum" | "none"

    Returns:
        loss tensor (scalar if reduced)
    """
    if pred.shape != target.shape:
        raise ValueError(f"Shape mismatch: pred{pred.shape} vs target{target.shape}")

    diff = pred - target
    loss = torch.sqrt(diff * diff + eps * eps)

    if reduction == "mean":
        return loss.mean()
    if reduction == "sum":
        return loss.sum()
    if reduction == "none":
        return loss
    raise ValueError("reduction must be one of {'mean','sum','none'}")




def GradientDifferenceLossCharbonnier( pred, target):
    grad_pred_x = pred[:, :, :, 1:] - pred[:, :, :, :-1]
    grad_target_x = target[:, :, :, 1:] - target[:, :, :, :-1]

    grad_pred_y = pred[:, :, 1:, :] - pred[:, :, :-1, :]
    grad_target_y = target[:, :, 1:, :] - target[:, :, :-1, :]

    return (
        charbonnier_loss(grad_pred_x, grad_target_x) +
        charbonnier_loss(grad_pred_y, grad_target_y)
    )

def cvae_loss(x, scaled_x_hat, x_hat, mu, logvar, beta=1e-3):
    mean = x.mean(dim=(1,2,3), keepdim=True) 
    std = x.std(dim=(1,2,3), keepdim=True) + 1e-12 
    x_norm=(x-mean)/std 
    recon = charbonnier_loss(x, x_hat) 
    recon_detail = charbonnier_loss(x_norm,scaled_x_hat)
    recon_detail_2 = GradientDifferenceLossCharbonnier(x_norm,scaled_x_hat)
    kl = kl_divergence_gaussian(mu, logvar) 

    return (1-beta)*(0.2*recon + 0.6*recon_detail + 0.2*recon_detail_2) + beta * kl, {"recon": recon.detach(),"recon_detail":recon_detail.detach(), "kl": kl.detach()}

def draw_latent(mu, logvar, clamp=(-1, 1)): 
    if clamp is not None: 
        logvar = torch.clamp(logvar, min=clamp[0], max=clamp[1]) 
        mu = mu.view(mu.size(0), -1) 
        logvar = logvar.view(logvar.size(0), -1) 
        plt.figure(figsize=(8, 4)) 
        plt.subplot(1, 2, 1) 
        plt.hist(mu.flatten().detach().cpu(), bins=100) 
        plt.subplot(1, 2, 2) 
        plt.hist(logvar.flatten().detach().cpu(), bins=100) 
        plt.title("Image 1") 
        plt.show()

def train_one_epoch(model, loader, device, opt, model_param,epoch): 
    model.train() 
    total = 0.0 
    count=0 
    beta_target=1e-3
    warmup_epochs=10 
    warm = 1 #min(1.0, (epoch + 1) / max(1, warmup_epochs)) 
    beta = beta_target * warm 
    for i, batch in enumerate(loader): 
        imags=batch['image'] 
        conds=batch['cond'] 
        for b in range(len(imags)): 
            s_batch = {'image':torch.stack(imags[b]).to(device),'cond':torch.Tensor(np.array(conds[b])).to(device)} 
            scaled_x_hat,x_hat, mu, logvar, _ = model(s_batch['image']) 
            loss, parts = cvae_loss(s_batch['image'], scaled_x_hat,x_hat, mu, logvar, beta=beta) 
            opt.zero_grad() 
            loss.backward() 
            opt.step() 
            total += float(loss.item())
            count+=1 
            if count % 50 == 0: 
                print('[TRAIN] epoch: ',epoch,'batch: ',i,'step: ',count,'loss: ',float(loss.item()),'recon_detail loss: ', parts['recon_detail'] ,'kl loss: ', parts['kl']) 
                origin_image=torch.stack(imags[b])[0,:][(model_param['in_channels']-1)//2] 
                pred_image=x_hat[0,:][(model_param['in_channels']-1)//2].cpu()
                draw_latent(mu, logvar, clamp=(-1, 1))
                draw(origin_image,pred_image,model_param) 
        del batch 
        gc.collect() 
    return total / max(1, count)
@torch.no_grad()
def eval_one_epoch(model, loader, device,  model_param,epoch):
    model.eval()
    total = 0.0 
    count=0 
    beta_target=1e-1
    warmup_epochs=10 
    warm = min(1.0, (epoch + 1) / max(1, warmup_epochs)) 
    beta = beta_target * warm 
    for i, batch in enumerate(loader): 
        imags=batch['image'] 
        conds=batch['cond'] 
        for b in range(len(imags)): 
            s_batch = {'image':torch.stack(imags[b]).to(device),'cond':torch.Tensor(np.array(conds[b])).to(device)} 
            scaled_x_hat,x_hat, mu, logvar, _ = model(s_batch['image']) 
            loss, parts = cvae_loss(s_batch['image'], scaled_x_hat,x_hat, mu, logvar, beta=beta) 
            total += float(loss.item())
            count+=1 
            if count % 20 == 0: 
                print('[VALID] epoch: ',epoch,'batch: ',i,'step: ',count,'loss: ',float(loss.item()),'kl loss: ', parts['kl']) 
                origin_image=torch.stack(imags[b])[0,:][(model_param['in_channels']-1)//2] 
                pred_image=x_hat[0,:][(model_param['in_channels']-1)//2].cpu()
                draw(origin_image,pred_image,model_param) 
        del batch 
        gc.collect() 
    return total / max(1, count)

def main():
    root = "./data"
    if torch.cuda.is_available() :
        device='cuda'
    elif torch.backends.mps.is_available() :
        device='mps'
    else :
        device='cpu'

    model_param={ 'in_channels':3, 
                'out_channels':3,
                'GRID':64,
                'loss_scale':1.0,
                'learning_rate':1e-3,
                'num_epochs':1000,
                'base':256,
                'latent_dim':256,
                'batch_size':128,
                'depth':4 } 
    
    train_ds = MeshDataset(root_dir=root,type='train',GRID=model_param['GRID'],in_channels=model_param['in_channels']) 
    val_ds= MeshDataset(root_dir=root,type='valid',GRID=model_param['GRID'],in_channels=model_param['in_channels']) 

    train_loader = DataLoader(train_ds, batch_size=model_param['batch_size'], shuffle=True, collate_fn=collate_flatten) 
    val_loader = DataLoader(val_ds, batch_size=model_param['batch_size'], shuffle=False, collate_fn=collate_flatten) 
    example = train_ds[0] 
    model_param['cond_dim']=len(example['cond'][0]) 
    model_param['dataset_scale_info']=train_ds.scale_info 

    model = ScalingVAE3( in_channels=model_param['in_channels'], 
                latent_dim=model_param['latent_dim'], 
                base=model_param['base'],
                depth=model_param['depth'] ).to(device)
    ckpt = torch.load("mesh_invariant_diffustion_vae4_2_early_epoch000.pt", map_location=device)
    model.load_state_dict(ckpt)
    model.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=model_param['learning_rate'], weight_decay=1e-6)
    loss_dict={}
    for epoch in range(model_param['num_epochs']):        
        train_loss = train_one_epoch(model, train_loader, device, optimizer,model_param,epoch)
        val_loss = eval_one_epoch(model, val_loader, device,model_param,epoch)
        loss_dict[epoch] = {'train_loss':train_loss, 'val_loss':val_loss}   
        print(f"Epoch {epoch+1}/{model_param['num_epochs']}, Train Loss: {train_loss:.6e}, Val Loss: {val_loss:.6e}")  
        improved = early_stopping.step(val_loss)
        with open(f"loss_history_diffustion_vae4_1.json", "w", encoding="utf-8") as f:
            json.dump(loss_dict, f, indent=2)
        if improved:
            best_val = val_loss
            # print(eval_one_epoch_sample_mse(model, val_loader, device, sched))
            torch.save(model.state_dict(), f"mesh_invariant_diffustion_vae4_2_early_epoch{str(epoch).zfill(3)}.pt")  # best만 저장

            with open(f"model_param_diffustion_vae4_2_early.json", "w", encoding="utf-8") as f:
                json.dump(model_param, f, indent=2)
        if early_stopping.should_stop:
            print(
                f"\n Early stopping at epoch {epoch} "
                f"(best val = {best_val:.6e})"
            )
            break
        if epoch%2==0:
            torch.save(model.state_dict(), f"mesh_invariant_diffustion_vae4_2_epoch{str(epoch).zfill(3)}.pt")
    torch.save(model.state_dict(), "mesh_invariant_diffustion_vae4_2.pt")
    with open(f"model_param_diffusion_vae4_2.json", "w", encoding="utf-8") as f:
        json.dump(model_param, f, indent=2) 

if __name__ == "__main__":
    main()
# Out:
# 100%|██████████| 805/805 [00:05<00:00, 139.07it/s]
# Loading FEM graph dataset...
# Build Complete FEM graph dataset...
# 100%|██████████| 805/805 [00:05<00:00, 142.28it/s]
# Loading FEM graph dataset...
# Build Complete FEM graph dataset...
# [TRAIN] epoch:  0 batch:  0 step:  50 loss:  0.2011386752128601 recon_detail loss:  tensor(0.2217, device='mps:0') kl loss:  tensor(42.3724, device='mps:0')
# vmin -0.18477266 vmax -0.18449622
# [TRAIN] epoch:  0 batch:  1 step:  100 loss:  0.19990509748458862 recon_detail loss:  tensor(0.2222, device='mps:0') kl loss:  tensor(39.9826, device='mps:0')
# vmin -0.18922509 vmax -0.18019506
# [TRAIN] epoch:  0 batch:  2 step:  150 loss:  0.196268692612648 recon_detail loss:  tensor(0.2172, device='mps:0') kl loss:  tensor(39.3782, device='mps:0')
# vmin -0.18989974 vmax -0.18023105
# [TRAIN] epoch:  0 batch:  3 step:  200 loss:  0.20633916556835175 recon_detail loss:  tensor(0.2324, device='mps:0') kl loss:  tensor(40.5015, device='mps:0')
# vmin -0.18674392 vmax -0.1823984
# [TRAIN] epoch:  0 batch:  3 step:  250 loss:  0.1877492368221283 recon_detail loss:  tensor(0.2076, device='mps:0') kl loss:  tensor(37.5553, device='mps:0')
# vmin -0.18675 vmax -0.18239902
# [TRAIN] epoch:  0 batch:  4 step:  300 loss:  0.17952455580234528 recon_detail loss:  tensor(0.1976, device='mps:0') kl loss:  tensor(36.6845, device='mps:0')
# vmin -0.18494213 vmax -0.18428653
# [TRAIN] epoch:  0 batch:  5 step:  350 loss:  0.18472130596637726 recon_detail loss:  tensor(0.1975, device='mps:0') kl loss:  tensor(40.2089, device='mps:0')
# vmin -0.18519382 vmax -0.18397214
# [VALID] epoch:  0 batch:  0 step:  20 loss:  0.5446479320526123 kl loss:  tensor(37.3630, device='mps:0')
# vmin -0.1846668 vmax -0.184548
# [VALID] epoch:  0 batch:  0 step:  40 loss:  0.5300241708755493 kl loss:  tensor(37.1635, device='mps:0')
# vmin -0.18466386 vmax -0.1845452
# [VALID] epoch:  0 batch:  0 step:  60 loss:  0.5312357544898987 kl loss:  tensor(36.9451, device='mps:0')
# vmin -0.18463898 vmax -0.18457314
# Epoch 1/1000, Train Loss: 2.125720e-01, Val Loss: 5.323412e-01
# [TRAIN] epoch:  1 batch:  0 step:  50 loss:  0.17823873460292816 recon_detail loss:  tensor(0.1968, device='mps:0') kl loss:  tensor(34.7139, device='mps:0')
# vmin -0.18401232 vmax -0.18350114
# [TRAIN] epoch:  1 batch:  1 step:  100 loss:  0.17388398945331573 recon_detail loss:  tensor(0.1834, device='mps:0') kl loss:  tensor(38.1628, device='mps:0')
# vmin -0.18579285 vmax -0.1833742
# [TRAIN] epoch:  1 batch:  2 step:  150 loss:  0.18981146812438965 recon_detail loss:  tensor(0.2052, device='mps:0') kl loss:  tensor(40.1447, device='mps:0')
# vmin -0.18479617 vmax -0.1844546
# [TRAIN] epoch:  1 batch:  3 step:  200 loss:  0.19063371419906616 recon_detail loss:  tensor(0.2131, device='mps:0') kl loss:  tensor(37.0804, device='mps:0')
# vmin -0.18542416 vmax -0.18378091
# [TRAIN] epoch:  1 batch:  3 step:  250 loss:  0.17131604254245758 recon_detail loss:  tensor(0.1832, device='mps:0') kl loss:  tensor(36.2023, device='mps:0')
# vmin -0.18539266 vmax -0.1837309
# [TRAIN] epoch:  1 batch:  4 step:  300 loss:  0.18270957469940186 recon_detail loss:  tensor(0.2082, device='mps:0') kl loss:  tensor(33.4179, device='mps:0')
# vmin -0.18499519 vmax -0.18451002
# [TRAIN] epoch:  1 batch:  5 step:  350 loss:  0.17572766542434692 recon_detail loss:  tensor(0.1941, device='mps:0') kl loss:  tensor(34.0438, device='mps:0')
# vmin -0.18468112 vmax -0.18450895
# [VALID] epoch:  1 batch:  0 step:  20 loss:  1.07239830493927 kl loss:  tensor(45.7522, device='mps:0')
# vmin -0.18465784 vmax -0.18454885
# [VALID] epoch:  1 batch:  0 step:  40 loss:  1.0668113231658936 kl loss:  tensor(45.4983, device='mps:0')
# vmin -0.18464941 vmax -0.18455653
# [VALID] epoch:  1 batch:  0 step:  60 loss:  1.0714423656463623 kl loss:  tensor(45.6961, device='mps:0')
# vmin -0.18465784 vmax -0.18454885
# Epoch 2/1000, Train Loss: 1.797625e-01, Val Loss: 1.074106e+00
# [TRAIN] epoch:  2 batch:  0 step:  50 loss:  0.16372621059417725 recon_detail loss:  tensor(0.1777, device='mps:0') kl loss:  tensor(33.1467, device='mps:0')
# vmin -0.18476313 vmax -0.1844702
# [TRAIN] epoch:  2 batch:  1 step:  100 loss:  0.16882352530956268 recon_detail loss:  tensor(0.1846, device='mps:0') kl loss:  tensor(32.8730, device='mps:0')
# vmin -0.18949962 vmax -0.17994983
# [TRAIN] epoch:  2 batch:  2 step:  150 loss:  0.17792469263076782 recon_detail loss:  tensor(0.1984, device='mps:0') kl loss:  tensor(33.2897, device='mps:0')
# vmin -0.18589117 vmax -0.18271522
# [TRAIN] epoch:  2 batch:  3 step:  200 loss:  0.19561584293842316 recon_detail loss:  tensor(0.2181, device='mps:0') kl loss:  tensor(38.3318, device='mps:0')
# vmin -0.18931393 vmax -0.17936224
# [TRAIN] epoch:  2 batch:  3 step:  250 loss:  0.1713750809431076 recon_detail loss:  tensor(0.1748, device='mps:0') kl loss:  tensor(40.9768, device='mps:0')
# vmin -0.18928914 vmax -0.17941202
# [TRAIN] epoch:  2 batch:  4 step:  300 loss:  0.1652248203754425 recon_detail loss:  tensor(0.1745, device='mps:0') kl loss:  tensor(35.3263, device='mps:0')
# vmin -0.18468092 vmax -0.1845333
# [TRAIN] epoch:  2 batch:  5 step:  350 loss:  0.1720367670059204 recon_detail loss:  tensor(0.1906, device='mps:0') kl loss:  tensor(32.8027, device='mps:0')
# vmin -0.18484224 vmax -0.18441595
# [VALID] epoch:  2 batch:  0 step:  20 loss:  1.2743946313858032 kl loss:  tensor(37.2150, device='mps:0')
# vmin -0.18464936 vmax -0.18455409
# [VALID] epoch:  2 batch:  0 step:  40 loss:  1.2529704570770264 kl loss:  tensor(36.7466, device='mps:0')
# vmin -0.18464825 vmax -0.18455929
# [VALID] epoch:  2 batch:  0 step:  60 loss:  1.2688062191009521 kl loss:  tensor(37.1540, device='mps:0')
# vmin -0.18464936 vmax -0.18455409
# Epoch 3/1000, Train Loss: 1.739983e-01, Val Loss: 1.276084e+00
# [TRAIN] epoch:  3 batch:  0 step:  50 loss:  0.16751691699028015 recon_detail loss:  tensor(0.1842, device='mps:0') kl loss:  tensor(32.1214, device='mps:0')
# vmin -0.18462932 vmax -0.18459924
# [TRAIN] epoch:  3 batch:  1 step:  100 loss:  0.15688379108905792 recon_detail loss:  tensor(0.1654, device='mps:0') kl loss:  tensor(34.0809, device='mps:0')
# vmin -0.19176508 vmax -0.1768506
# [TRAIN] epoch:  3 batch:  2 step:  150 loss:  0.17468543350696564 recon_detail loss:  tensor(0.1943, device='mps:0') kl loss:  tensor(31.9007, device='mps:0')
# vmin -0.18488845 vmax -0.18451719
# [TRAIN] epoch:  3 batch:  3 step:  200 loss:  0.18082702159881592 recon_detail loss:  tensor(0.2011, device='mps:0') kl loss:  tensor(35.1173, device='mps:0')
# vmin -0.18643592 vmax -0.18260738
# [TRAIN] epoch:  3 batch:  3 step:  250 loss:  0.15709246695041656 recon_detail loss:  tensor(0.1673, device='mps:0') kl loss:  tensor(33.1829, device='mps:0')
# vmin -0.18644156 vmax -0.18257575
# [TRAIN] epoch:  3 batch:  4 step:  300 loss:  0.16442634165287018 recon_detail loss:  tensor(0.1726, device='mps:0') kl loss:  tensor(36.6143, device='mps:0')
# vmin -0.19345078 vmax -0.19213451
# [TRAIN] epoch:  3 batch:  5 step:  350 loss:  0.16111072897911072 recon_detail loss:  tensor(0.1712, device='mps:0') kl loss:  tensor(33.9413, device='mps:0')
# vmin -0.18540187 vmax -0.18379153
# [VALID] epoch:  3 batch:  0 step:  20 loss:  1.7693018913269043 kl loss:  tensor(40.2327, device='mps:0')
# vmin -0.18463953 vmax -0.184577
# [VALID] epoch:  3 batch:  0 step:  40 loss:  1.7352674007415771 kl loss:  tensor(39.3691, device='mps:0')
# vmin -0.18463898 vmax -0.18457314
# [VALID] epoch:  3 batch:  0 step:  60 loss:  1.7134363651275635 kl loss:  tensor(39.0958, device='mps:0')
# vmin -0.18464461 vmax -0.18457964
# Epoch 4/1000, Train Loss: 1.682782e-01, Val Loss: 1.729845e+00
# [TRAIN] epoch:  4 batch:  0 step:  50 loss:  0.1574748456478119 recon_detail loss:  tensor(0.1705, device='mps:0') kl loss:  tensor(31.1751, device='mps:0')
# vmin -0.18473747 vmax -0.18449026
# [TRAIN] epoch:  4 batch:  1 step:  100 loss:  0.15496358275413513 recon_detail loss:  tensor(0.1623, device='mps:0') kl loss:  tensor(33.9405, device='mps:0')
# vmin -0.18722978 vmax -0.18164487
# [TRAIN] epoch:  4 batch:  2 step:  150 loss:  0.17103296518325806 recon_detail loss:  tensor(0.1894, device='mps:0') kl loss:  tensor(31.8605, device='mps:0')
# vmin -0.18592504 vmax -0.18328679
# [TRAIN] epoch:  4 batch:  3 step:  200 loss:  0.17458048462867737 recon_detail loss:  tensor(0.1951, device='mps:0') kl loss:  tensor(32.1248, device='mps:0')
# vmin -0.18478632 vmax -0.18461025
# [TRAIN] epoch:  4 batch:  3 step:  250 loss:  0.15331435203552246 recon_detail loss:  tensor(0.1641, device='mps:0') kl loss:  tensor(31.9576, device='mps:0')
# vmin -0.18476169 vmax -0.18452805
# [TRAIN] epoch:  4 batch:  4 step:  300 loss:  0.14250585436820984 recon_detail loss:  tensor(0.1464, device='mps:0') kl loss:  tensor(32.2764, device='mps:0')
# vmin -0.18509214 vmax -0.18419723
# [TRAIN] epoch:  4 batch:  5 step:  350 loss:  0.1598317176103592 recon_detail loss:  tensor(0.1711, device='mps:0') kl loss:  tensor(34.0724, device='mps:0')
# vmin -0.18471546 vmax -0.18449327
# [VALID] epoch:  4 batch:  0 step:  20 loss:  1.8951654434204102 kl loss:  tensor(34.9181, device='mps:0')
# vmin -0.18464825 vmax -0.18455929
# [VALID] epoch:  4 batch:  0 step:  40 loss:  1.9022047519683838 kl loss:  tensor(34.9774, device='mps:0')
# vmin -0.18465438 vmax -0.18455039
# [VALID] epoch:  4 batch:  0 step:  60 loss:  1.9179364442825317 kl loss:  tensor(35.2390, device='mps:0')
# vmin -0.18464202 vmax -0.18457794
# Epoch 5/1000, Train Loss: 1.631947e-01, Val Loss: 1.900740e+00
# [TRAIN] epoch:  5 batch:  0 step:  50 loss:  0.15470001101493835 recon_detail loss:  tensor(0.1649, device='mps:0') kl loss:  tensor(32.5342, device='mps:0')
# vmin -0.18592504 vmax -0.18328679
# [TRAIN] epoch:  5 batch:  1 step:  100 loss:  0.15628841519355774 recon_detail loss:  tensor(0.1676, device='mps:0') kl loss:  tensor(32.3269, device='mps:0')
# vmin -0.18496905 vmax -0.1842489
# [TRAIN] epoch:  5 batch:  2 step:  150 loss:  0.16425356268882751 recon_detail loss:  tensor(0.1756, device='mps:0') kl loss:  tensor(35.3472, device='mps:0')
# vmin -0.18473063 vmax -0.18448691
# [TRAIN] epoch:  5 batch:  3 step:  200 loss:  0.17662112414836884 recon_detail loss:  tensor(0.1936, device='mps:0') kl loss:  tensor(35.0038, device='mps:0')
# vmin -0.18507531 vmax -0.18423633
# [TRAIN] epoch:  5 batch:  3 step:  250 loss:  0.14760102331638336 recon_detail loss:  tensor(0.1577, device='mps:0') kl loss:  tensor(30.4482, device='mps:0')
# vmin -0.18507627 vmax -0.18418619
# [TRAIN] epoch:  5 batch:  4 step:  300 loss:  0.14987891912460327 recon_detail loss:  tensor(0.1556, device='mps:0') kl loss:  tensor(33.8927, device='mps:0')
# vmin -0.18633716 vmax -0.18307114
# [TRAIN] epoch:  5 batch:  5 step:  350 loss:  0.14953933656215668 recon_detail loss:  tensor(0.1574, device='mps:0') kl loss:  tensor(32.4052, device='mps:0')
# vmin -0.18550934 vmax -0.18374676
# [VALID] epoch:  5 batch:  0 step:  20 loss:  2.2501351833343506 kl loss:  tensor(34.9371, device='mps:0')
# vmin -0.18466386 vmax -0.1845452
# [VALID] epoch:  5 batch:  0 step:  40 loss:  2.343651294708252 kl loss:  tensor(36.4045, device='mps:0')
# vmin -0.18464936 vmax -0.18455409
# [VALID] epoch:  5 batch:  0 step:  60 loss:  2.301239252090454 kl loss:  tensor(35.7692, device='mps:0')
# vmin -0.18464936 vmax -0.18455409
# Epoch 6/1000, Train Loss: 1.601506e-01, Val Loss: 2.301347e+00
# [TRAIN] epoch:  6 batch:  0 step:  50 loss:  0.1451670378446579 recon_detail loss:  tensor(0.1571, device='mps:0') kl loss:  tensor(28.7676, device='mps:0')
# vmin -0.18496405 vmax -0.1843182
# [TRAIN] epoch:  6 batch:  1 step:  100 loss:  0.1530424803495407 recon_detail loss:  tensor(0.1636, device='mps:0') kl loss:  tensor(33.0660, device='mps:0')
# vmin -0.18465433 vmax -0.1846034
# [TRAIN] epoch:  6 batch:  2 step:  150 loss:  0.15483906865119934 recon_detail loss:  tensor(0.1638, device='mps:0') kl loss:  tensor(33.7472, device='mps:0')
# vmin -0.1847573 vmax -0.18442556
# [TRAIN] epoch:  6 batch:  3 step:  200 loss:  0.16260215640068054 recon_detail loss:  tensor(0.1794, device='mps:0') kl loss:  tensor(30.1705, device='mps:0')
# vmin -0.18943934 vmax -0.17990805
# [TRAIN] epoch:  6 batch:  3 step:  250 loss:  0.1353573054075241 recon_detail loss:  tensor(0.1419, device='mps:0') kl loss:  tensor(29.5550, device='mps:0')
# vmin -0.18951412 vmax -0.18004881
# [TRAIN] epoch:  6 batch:  4 step:  300 loss:  0.14868278801441193 recon_detail loss:  tensor(0.1587, device='mps:0') kl loss:  tensor(31.3957, device='mps:0')
# vmin -0.1851378 vmax -0.18389475
# [TRAIN] epoch:  6 batch:  5 step:  350 loss:  0.16099728643894196 recon_detail loss:  tensor(0.1699, device='mps:0') kl loss:  tensor(36.5714, device='mps:0')
# vmin -0.1858431 vmax -0.18350355
# [VALID] epoch:  6 batch:  0 step:  20 loss:  2.3499855995178223 kl loss:  tensor(31.3779, device='mps:0')
# vmin -0.18463898 vmax -0.18457314
# [VALID] epoch:  6 batch:  0 step:  40 loss:  2.336414098739624 kl loss:  tensor(31.2044, device='mps:0')
# vmin -0.18465784 vmax -0.18454885
# [VALID] epoch:  6 batch:  0 step:  60 loss:  2.3505396842956543 kl loss:  tensor(31.4788, device='mps:0')
# vmin -0.1846668 vmax -0.184548
# Epoch 7/1000, Train Loss: 1.554736e-01, Val Loss: 2.362628e+00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 276
#     273         json.dump(model_param, f, indent=2)
#     275 if __name__ == "__main__":
# --> 276     main()
#
# Cell In[1], line 249, in main()
#     247 loss_dict={}
#     248 for epoch in range(model_param['num_epochs']):
# --> 249     train_loss = train_one_epoch(model, train_loader, device, optimizer,model_param,epoch)
#     250     val_loss = eval_one_epoch(model, val_loader, device,model_param,epoch)
#     251     loss_dict[epoch] = {'train_loss':train_loss, 'val_loss':val_loss}
#
# Cell In[1], line 162, in train_one_epoch(model, loader, device, opt, model_param, epoch)
#     160 warm = 1 #min(1.0, (epoch + 1) / max(1, warmup_epochs))
#     161 beta = beta_target * warm
# --> 162 for i, batch in enumerate(loader):
#     163     imags=batch['image']
#     164     conds=batch['cond']
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/general/lib/python3.11/site-packages/torch/utils/data/dataloader.py:630, in _BaseDataLoaderIter.__next__(self)
#     627 if self._sampler_iter is None:
#     628     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     629     self._reset()  # type: ignore[call-arg]
# --> 630 data = self._next_data()
#     631 self._num_yielded += 1
#     632 if self._dataset_kind == _DatasetKind.Iterable and \
#     633         self._IterableDataset_len_called is not None and \
#     634         self._num_yielded > self._IterableDataset_len_called:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/general/lib/python3.11/site-packages/torch/utils/data/dataloader.py:674, in _SingleProcessDataLoaderIter._next_data(self)
#     672 def _next_data(self):
#     673     index = self._next_index()  # may raise StopIteration
# --> 674     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     675     if self._pin_memory:
#     676         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/general/lib/python3.11/site-packages/torch/utils/data/_utils/fetch.py:51, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/general/lib/python3.11/site-packages/torch/utils/data/_utils/fetch.py:51, in <listcomp>(.0)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File ~/github.com/simulation_graph_app/aluminium_free_free/fem_dataset_to_image_full_mesh_diffusion.py:263, in FemImageDataset.__getitem__(self, idx)
#     262 def __getitem__(self, idx):
# --> 263     return self._load_image(self.samples[idx])
#
# File ~/github.com/simulation_graph_app/aluminium_free_free/fem_dataset_to_image_full_mesh_diffusion.py:249, in FemImageDataset._load_image(self, sd)
#     246 for z_idx in range(self.GRID):
#     247     # z_idx = np.random.randint(0, self.GRID)
#     248     K=int((self.in_channels-1)/2)
# --> 249     image=csvToImage_25d_stack(disp_df, z_idx, K=K,GRID=self.GRID,scale=origin_params)
#     250     # image: (W,H,D,C) numpy
#     251     vol = torch.from_numpy(image).float()
#
# File ~/github.com/simulation_graph_app/aluminium_free_free/fem_dataset_to_image_full_mesh_diffusion.py:115, in csvToImage_25d_stack(df, z_idx, K, GRID, scale)
#     113 for dz in range(-K, K + 1):
#     114     zi = np.clip(z_idx + dz, 0, GRID - 1)
# --> 115     img = csvToImage_25d_slice(
#     116         df,
#     117         zi,
#     118         GRID,
#     119         scale
#     120     )
#     121     slices.append(img)
#     123 return np.stack(slices, axis=0)
#
# File ~/github.com/simulation_graph_app/aluminium_free_free/fem_dataset_to_image_full_mesh_diffusion.py:93, in csvToImage_25d_slice(df, z_idx, GRID, scale)
#      84 grid_x, grid_y = np.meshgrid(
#      85     np.linspace(xmin, xmax, GRID),
#      86     np.linspace(ymin, ymax, GRID),
#      87     indexing="ij"
#      88 )
#      90 # -----------------------------
#      91 # 2D interpolation
#      92 # -----------------------------
# ---> 93 img = griddata(
#      94     sdf[["x", "y"]].values,
#      95     sdf["uz"].values,
#      96     (grid_x, grid_y),
#      97     method="nearest",   # ← 안정 + 빠름
#      98 ).astype(np.float32)
#     100 return img
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/general/lib/python3.11/site-packages/scipy/interpolate/_ndgriddata.py:271, in griddata(points, values, xi, method, fill_value, rescale)
#     269 elif method == 'nearest':
#     270     ip = NearestNDInterpolator(points, values, rescale=rescale)
# --> 271     return ip(xi)
#     272 elif method == 'linear':
#     273     ip = LinearNDInterpolator(points, values, fill_value=fill_value,
#     274                               rescale=rescale)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/general/lib/python3.11/site-packages/scipy/interpolate/_ndgriddata.py:116, in NearestNDInterpolator.__call__(self, *args)
#     114 xi = self._check_call_shape(xi)
#     115 xi = self._scale_x(xi)
# --> 116 dist, i = self.tree.query(xi)
#     117 return self.values[i]
#
# File _ckdtree.pyx:830, in scipy.spatial._ckdtree.cKDTree.query()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/general/lib/python3.11/site-packages/numpy/core/fromnumeric.py:195, in _reshape_dispatcher(a, newshape, order)
#      97     """
#      98     Take elements from an array along an axis.
#      99
#    (...)
#     190            [5, 7]])
#     191     """
#     192     return _wrapfunc(a, 'take', indices, axis=axis, out=out, mode=mode)
# --> 195 def _reshape_dispatcher(a, newshape, order=None):
#     196     return (a,)
#     199 # not deprecated --- copy if necessary, view otherwise
#
# KeyboardInterrupt:

# %%
import torch
import torch.nn.functional as F
from fem_dataset_to_image_full_mesh_diffusion import FemImageDataset as MeshDataset
from fem_model import ScalingVAE3
import json
from torch.utils.data import DataLoader
from utils import EarlyStopping
import gc
import numpy as np
import matplotlib.pyplot as plt


early_stopping = EarlyStopping(
    patience=10,     # FEM/GNN은 15~30 권장
    min_delta=1e-6,  # loss 스케일에 맞게
    mode="min"
)
def collate_flatten(batch): 
    images, conds = [], [] 
    batch_size=len(batch) 
    step_num_in_batch=len(batch[0]["image"]) 
    idxs=[] 
    for i in range(batch_size): 
        idx = torch.randperm(len(batch[0]["image"])) 
        idxs.append(idx) 
        # print(batch[i]['min_max'])
    idxs=np.array(idxs).T 

    for i in range(step_num_in_batch): 
        batch_images=[] 
        batch_conds=[] 
        for b_i,b in enumerate(batch): 
            id=idxs[i][b_i] 
            batch_images.append(b['image'][id]) 
            batch_conds.append(b['cond'][id]) 
        images.append(batch_images) 
        conds.append(batch_conds) 
    return { "image": images, "cond": conds, }

def draw(data1,data2,model_param): 
    stride=1 
    clip_q=(0.25,0.75) 
    cmap="jet" 
    ql, qh = np.quantile(data1.cpu().detach().numpy(), clip_q) 
    Uf1_clip = np.clip(data1.cpu().detach().numpy(), ql, qh) 
    ql, qh = np.quantile(data2.cpu().detach().numpy(), clip_q) 
    Uf2_clip = np.clip(data2.cpu().detach().numpy(), ql, qh) 
    print('vmin',Uf1_clip.min(),'vmax',Uf1_clip.max())
    plt.figure(figsize=(8, 4)) 
    plt.subplot(1, 3, 1) 
    plt.imshow(Uf1_clip, cmap="gray",vmin=Uf1_clip.min(),vmax=Uf1_clip.max()) 
    plt.title("Image 1") 
    plt.axis("off") 
    plt.subplot(1, 3, 2) 
    plt.imshow(Uf2_clip, cmap="gray",vmin=Uf1_clip.min(),vmax=Uf1_clip.max())
    plt.title("Image 2") 
    plt.axis("off") 
    plt.subplot(1, 3, 3) 
    plt.imshow(np.abs(Uf1_clip-Uf2_clip), cmap="gray",vmin=Uf1_clip.min(),vmax=Uf1_clip.max())
    plt.title("Image 3") 
    plt.axis("off")
    plt.tight_layout() 
    plt.show()

def kl_divergence_gaussian(mu, logvar, clamp=(-0.3, 0.3)):
    """
    KL( N(mu, var) || N(0, I) )
    Supports mu/logvar with shape:
      [B, Z] or [B, C, H, W] or [B, ...]
    """
    if clamp is not None:
        logvar = torch.clamp(logvar, min=clamp[0], max=clamp[1])

    # flatten all non-batch dimensions
    mu = mu.view(mu.size(0), -1)
    logvar = logvar.view(logvar.size(0), -1)

    kl = 0.5 * torch.sum(
        torch.exp(logvar) + mu**2 - 1.0 - logvar,
        dim=1
    )

    return kl.mean()

def charbonnier_loss(pred: torch.Tensor,
                     target: torch.Tensor,
                     eps: float = 1e-8,
                     reduction: str = "mean") -> torch.Tensor:
    """
    Charbonnier loss (a smooth L1 / pseudo-Huber variant):
        L = sqrt((pred - target)^2 + eps^2)

    Args:
        pred, target: same shape tensors
        eps: smoothing term (bigger -> more L1-like near 0)
        reduction: "mean" | "sum" | "none"

    Returns:
        loss tensor (scalar if reduced)
    """
    if pred.shape != target.shape:
        raise ValueError(f"Shape mismatch: pred{pred.shape} vs target{target.shape}")

    diff = pred - target
    loss = torch.sqrt(diff * diff + eps * eps)

    if reduction == "mean":
        return loss.mean()
    if reduction == "sum":
        return loss.sum()
    if reduction == "none":
        return loss
    raise ValueError("reduction must be one of {'mean','sum','none'}")




def GradientDifferenceLossCharbonnier( pred, target):
    grad_pred_x = pred[:, :, :, 1:] - pred[:, :, :, :-1]
    grad_target_x = target[:, :, :, 1:] - target[:, :, :, :-1]

    grad_pred_y = pred[:, :, 1:, :] - pred[:, :, :-1, :]
    grad_target_y = target[:, :, 1:, :] - target[:, :, :-1, :]

    return (
        charbonnier_loss(grad_pred_x, grad_target_x) +
        charbonnier_loss(grad_pred_y, grad_target_y)
    )

def cvae_loss(x, scaled_x_hat, x_hat, mu, logvar, beta=1e-3):
    mean = x.mean(dim=(1,2,3), keepdim=True) 
    std = x.std(dim=(1,2,3), keepdim=True) + 1e-12 
    x_norm=(x-mean)/std 
    recon = charbonnier_loss(x, x_hat) 
    recon_detail = charbonnier_loss(x_norm,scaled_x_hat)
    recon_detail_2 = GradientDifferenceLossCharbonnier(x_norm,scaled_x_hat)
    kl = kl_divergence_gaussian(mu, logvar) 

    return (1-beta)*(0.2*recon + 0.6*recon_detail + 0.2*recon_detail_2) + beta * kl, {"recon": recon.detach(),"recon_detail":recon_detail.detach(), "kl": kl.detach()}

def draw_latent(mu, logvar, clamp=(-1, 1)): 
    if clamp is not None: 
        logvar = torch.clamp(logvar, min=clamp[0], max=clamp[1]) 
        mu = mu.view(mu.size(0), -1) 
        logvar = logvar.view(logvar.size(0), -1) 
        plt.figure(figsize=(8, 4)) 
        plt.subplot(1, 2, 1) 
        plt.hist(mu.flatten().detach().cpu(), bins=100) 
        plt.subplot(1, 2, 2) 
        plt.hist(logvar.flatten().detach().cpu(), bins=100) 
        plt.title("Image 1") 
        plt.show()

def train_one_epoch(model, loader, device, opt, model_param,epoch): 
    model.train() 
    total = 0.0 
    count=0 
    beta_target=1e-3
    warmup_epochs=10 
    warm = 1 #min(1.0, (epoch + 1) / max(1, warmup_epochs)) 
    beta = beta_target * warm 
    for i, batch in enumerate(loader): 
        imags=batch['image'] 
        conds=batch['cond'] 
        for b in range(len(imags)): 
            s_batch = {'image':torch.stack(imags[b]).to(device),'cond':torch.Tensor(np.array(conds[b])).to(device)} 
            scaled_x_hat,x_hat, mu, logvar, _ = model(s_batch['image']) 
            loss, parts = cvae_loss(s_batch['image'], scaled_x_hat,x_hat, mu, logvar, beta=beta) 
            opt.zero_grad() 
            loss.backward() 
            opt.step() 
            total += float(loss.item())
            count+=1 
            if count % 50 == 0: 
                print('[TRAIN] epoch: ',epoch,'batch: ',i,'step: ',count,'loss: ',float(loss.item()),'recon_detail loss: ', parts['recon_detail'] ,'kl loss: ', parts['kl']) 
                origin_image=torch.stack(imags[b])[0,:][(model_param['in_channels']-1)//2] 
                pred_image=x_hat[0,:][(model_param['in_channels']-1)//2].cpu()
                draw_latent(mu, logvar, clamp=(-1, 1))
                draw(origin_image,pred_image,model_param) 
        del batch 
        gc.collect() 
    return total / max(1, count)
@torch.no_grad()
def eval_one_epoch(model, loader, device,  model_param,epoch):
    model.eval()
    total = 0.0 
    count=0 
    beta_target=1e-3
    warmup_epochs=10 
    warm = 1
    beta = beta_target * warm 
    for i, batch in enumerate(loader): 
        imags=batch['image'] 
        conds=batch['cond'] 
        for b in range(len(imags)): 
            s_batch = {'image':torch.stack(imags[b]).to(device),'cond':torch.Tensor(np.array(conds[b])).to(device)} 
            scaled_x_hat,x_hat, mu, logvar, _ = model(s_batch['image']) 
            loss, parts = cvae_loss(s_batch['image'], scaled_x_hat,x_hat, mu, logvar, beta=beta) 
            total += float(loss.item())
            count+=1 
            if count % 20 == 0: 
                print('[VALID] epoch: ',epoch,'batch: ',i,'step: ',count,'loss: ',float(loss.item()),'kl loss: ', parts['kl']) 
                origin_image=torch.stack(imags[b])[0,:][(model_param['in_channels']-1)//2] 
                pred_image=x_hat[0,:][(model_param['in_channels']-1)//2].cpu()
                draw(origin_image,pred_image,model_param) 
        del batch 
        gc.collect() 
    return total / max(1, count)

def main():
    root = "./data"
    if torch.cuda.is_available() :
        device='cuda'
    elif torch.backends.mps.is_available() :
        device='mps'
    else :
        device='cpu'

    model_param={ 'in_channels':3, 
                'out_channels':3,
                'GRID':64,
                'loss_scale':1.0,
                'learning_rate':1e-3,
                'num_epochs':1000,
                'base':256,
                'latent_dim':256,
                'batch_size':128,
                'depth':4 } 
    
    train_ds = MeshDataset(root_dir=root,type='train',GRID=model_param['GRID'],in_channels=model_param['in_channels']) 
    val_ds= MeshDataset(root_dir=root,type='valid',GRID=model_param['GRID'],in_channels=model_param['in_channels']) 

    train_loader = DataLoader(train_ds, batch_size=model_param['batch_size'], shuffle=True, collate_fn=collate_flatten) 
    val_loader = DataLoader(val_ds, batch_size=model_param['batch_size'], shuffle=False, collate_fn=collate_flatten) 
    example = train_ds[0] 
    model_param['cond_dim']=len(example['cond'][0]) 
    model_param['dataset_scale_info']=train_ds.scale_info 

    model = ScalingVAE3( in_channels=model_param['in_channels'], 
                latent_dim=model_param['latent_dim'], 
                base=model_param['base'],
                depth=model_param['depth'] ).to(device)
    ckpt = torch.load("mesh_invariant_diffustion_vae4_2_epoch006.pt", map_location=device)
    model.load_state_dict(ckpt)
    model.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=model_param['learning_rate'], weight_decay=1e-6)
    loss_dict={}
    for epoch in range(model_param['num_epochs']):
        epoch=epoch+7        
        train_loss = train_one_epoch(model, train_loader, device, optimizer,model_param,epoch)
        val_loss = eval_one_epoch(model, val_loader, device,model_param,epoch)
        loss_dict[epoch] = {'train_loss':train_loss, 'val_loss':val_loss}   
        print(f"Epoch {epoch+1}/{model_param['num_epochs']}, Train Loss: {train_loss:.6e}, Val Loss: {val_loss:.6e}")  
        improved = early_stopping.step(val_loss)
        with open(f"loss_history_diffustion_vae4_2.json", "w", encoding="utf-8") as f:
            json.dump(loss_dict, f, indent=2)
        if improved:
            best_val = val_loss
            # print(eval_one_epoch_sample_mse(model, val_loader, device, sched))
            torch.save(model.state_dict(), f"mesh_invariant_diffustion_vae4_2_early_epoch{str(epoch).zfill(3)}.pt")  # best만 저장

            with open(f"model_param_diffustion_vae4_2_early.json", "w", encoding="utf-8") as f:
                json.dump(model_param, f, indent=2)
        if early_stopping.should_stop:
            print(
                f"\n Early stopping at epoch {epoch} "
                f"(best val = {best_val:.6e})"
            )
            break
        if epoch%2==0:
            torch.save(model.state_dict(), f"mesh_invariant_diffustion_vae4_2_epoch{str(epoch).zfill(3)}.pt")
    torch.save(model.state_dict(), "mesh_invariant_diffustion_vae4_2.pt")
    with open(f"model_param_diffusion_vae4_2.json", "w", encoding="utf-8") as f:
        json.dump(model_param, f, indent=2) 

if __name__ == "__main__":
    main()
# Out:
# 100%|██████████| 805/805 [00:05<00:00, 155.48it/s]
# Loading FEM graph dataset...
# Build Complete FEM graph dataset...
# 100%|██████████| 805/805 [00:05<00:00, 154.75it/s]
# Loading FEM graph dataset...
# Build Complete FEM graph dataset...
# [TRAIN] epoch:  7 batch:  0 step:  50 loss:  0.1418055146932602 recon_detail loss:  tensor(0.1466, device='mps:0') kl loss:  tensor(33.9785, device='mps:0')
# vmin -0.18497743 vmax -0.18425359
# [TRAIN] epoch:  7 batch:  1 step:  100 loss:  0.13435518741607666 recon_detail loss:  tensor(0.1404, device='mps:0') kl loss:  tensor(28.9044, device='mps:0')
# vmin -0.2656327 vmax -0.10130861
# [TRAIN] epoch:  7 batch:  2 step:  150 loss:  0.157881960272789 recon_detail loss:  tensor(0.1725, device='mps:0') kl loss:  tensor(31.6228, device='mps:0')
# vmin -0.22282211 vmax -0.14505254
# [TRAIN] epoch:  7 batch:  3 step:  200 loss:  0.16810950636863708 recon_detail loss:  tensor(0.1834, device='mps:0') kl loss:  tensor(32.9351, device='mps:0')
# vmin -0.18684551 vmax -0.183086
# [TRAIN] epoch:  7 batch:  3 step:  250 loss:  0.14870207011699677 recon_detail loss:  tensor(0.1653, device='mps:0') kl loss:  tensor(28.9937, device='mps:0')
# vmin -0.18525809 vmax -0.18349193
# [TRAIN] epoch:  7 batch:  4 step:  300 loss:  0.14163818955421448 recon_detail loss:  tensor(0.1468, device='mps:0') kl loss:  tensor(33.0247, device='mps:0')
# vmin -0.18540627 vmax -0.1828123
# [TRAIN] epoch:  7 batch:  5 step:  350 loss:  0.14556342363357544 recon_detail loss:  tensor(0.1493, device='mps:0') kl loss:  tensor(34.4065, device='mps:0')
# vmin -0.18669099 vmax -0.18253428
# [VALID] epoch:  7 batch:  0 step:  20 loss:  0.20377326011657715 kl loss:  tensor(36.8619, device='mps:0')
# vmin -0.1846609 vmax -0.18454589
# [VALID] epoch:  7 batch:  0 step:  40 loss:  0.19625549018383026 kl loss:  tensor(36.3965, device='mps:0')
# vmin -0.18466595 vmax -0.18454541
# [VALID] epoch:  7 batch:  0 step:  60 loss:  0.195321723818779 kl loss:  tensor(35.9281, device='mps:0')
# vmin -0.1846609 vmax -0.18454589
# Epoch 8/1000, Train Loss: 1.528406e-01, Val Loss: 1.976677e-01
# [TRAIN] epoch:  8 batch:  0 step:  50 loss:  0.1335633099079132 recon_detail loss:  tensor(0.1379, device='mps:0') kl loss:  tensor(31.8088, device='mps:0')
# vmin -0.18692225 vmax -0.18237317
# [TRAIN] epoch:  8 batch:  1 step:  100 loss:  0.13959771394729614 recon_detail loss:  tensor(0.1440, device='mps:0') kl loss:  tensor(33.5090, device='mps:0')
# vmin -0.18476745 vmax -0.18444154
# [TRAIN] epoch:  8 batch:  2 step:  150 loss:  0.1499699354171753 recon_detail loss:  tensor(0.1596, device='mps:0') kl loss:  tensor(31.4333, device='mps:0')
# vmin -0.18603437 vmax -0.18373273
# [TRAIN] epoch:  8 batch:  3 step:  200 loss:  0.1811782717704773 recon_detail loss:  tensor(0.2039, device='mps:0') kl loss:  tensor(33.3132, device='mps:0')
# vmin -0.18700446 vmax -0.18232581
# [TRAIN] epoch:  8 batch:  3 step:  250 loss:  0.12883171439170837 recon_detail loss:  tensor(0.1289, device='mps:0') kl loss:  tensor(33.0079, device='mps:0')
# vmin -0.18702206 vmax -0.18233564
# [TRAIN] epoch:  8 batch:  4 step:  300 loss:  4.683915138244629 recon_detail loss:  tensor(0.7618, device='mps:0') kl loss:  tensor(4202.8770, device='mps:0')
# vmin -0.18463026 vmax -0.1845883
# [TRAIN] epoch:  8 batch:  5 step:  350 loss:  0.27898353338241577 recon_detail loss:  tensor(0.2805, device='mps:0') kl loss:  tensor(83.6304, device='mps:0')
# vmin -0.18487869 vmax -0.18421257
# [VALID] epoch:  8 batch:  0 step:  20 loss:  0.24070748686790466 kl loss:  tensor(53.4820, device='mps:0')
# vmin -0.1846609 vmax -0.18454589
# [VALID] epoch:  8 batch:  0 step:  40 loss:  0.24007651209831238 kl loss:  tensor(54.1517, device='mps:0')
# vmin -0.18463953 vmax -0.184577
# [VALID] epoch:  8 batch:  0 step:  60 loss:  0.23747824132442474 kl loss:  tensor(53.3542, device='mps:0')
# vmin -0.18465784 vmax -0.18454885
# Epoch 9/1000, Train Loss: 6.517126e-01, Val Loss: 2.387642e-01
# [TRAIN] epoch:  9 batch:  0 step:  50 loss:  0.18766091763973236 recon_detail loss:  tensor(0.2046, device='mps:0') kl loss:  tensor(39.5134, device='mps:0')
# vmin -0.18489596 vmax -0.18433677
# [TRAIN] epoch:  9 batch:  1 step:  100 loss:  0.1786065697669983 recon_detail loss:  tensor(0.1994, device='mps:0') kl loss:  tensor(34.3685, device='mps:0')
# vmin -0.18478571 vmax -0.18442732
# [TRAIN] epoch:  9 batch:  2 step:  150 loss:  0.174115389585495 recon_detail loss:  tensor(0.1843, device='mps:0') kl loss:  tensor(37.6528, device='mps:0')
# vmin -0.18478538 vmax -0.18462701
# [TRAIN] epoch:  9 batch:  3 step:  200 loss:  0.18249288201332092 recon_detail loss:  tensor(0.2023, device='mps:0') kl loss:  tensor(35.3518, device='mps:0')
# vmin -0.18637998 vmax -0.18328947
# [TRAIN] epoch:  9 batch:  3 step:  250 loss:  0.15251480042934418 recon_detail loss:  tensor(0.1613, device='mps:0') kl loss:  tensor(34.7093, device='mps:0')
# vmin -0.18632625 vmax -0.18322898
# [TRAIN] epoch:  9 batch:  4 step:  300 loss:  0.15701724588871002 recon_detail loss:  tensor(0.1691, device='mps:0') kl loss:  tensor(35.2657, device='mps:0')
# vmin -0.18463223 vmax -0.18457511
# [TRAIN] epoch:  9 batch:  5 step:  350 loss:  0.1548967808485031 recon_detail loss:  tensor(0.1625, device='mps:0') kl loss:  tensor(36.6581, device='mps:0')
# vmin -0.18473168 vmax -0.18459997
# [VALID] epoch:  9 batch:  0 step:  20 loss:  0.20889446139335632 kl loss:  tensor(33.5688, device='mps:0')
# vmin -0.18463898 vmax -0.18457314
# [VALID] epoch:  9 batch:  0 step:  40 loss:  0.20316849648952484 kl loss:  tensor(33.2796, device='mps:0')
# vmin -0.18466386 vmax -0.1845452
# [VALID] epoch:  9 batch:  0 step:  60 loss:  0.19630201160907745 kl loss:  tensor(32.3025, device='mps:0')
# vmin -0.18463953 vmax -0.184577
# Epoch 10/1000, Train Loss: 1.712879e-01, Val Loss: 2.016635e-01
# [TRAIN] epoch:  10 batch:  0 step:  50 loss:  0.1378764808177948 recon_detail loss:  tensor(0.1440, device='mps:0') kl loss:  tensor(32.6765, device='mps:0')
# vmin -0.18487556 vmax -0.184371
# [TRAIN] epoch:  10 batch:  1 step:  100 loss:  0.14771614968776703 recon_detail loss:  tensor(0.1579, device='mps:0') kl loss:  tensor(32.8688, device='mps:0')
# vmin -0.18460694 vmax -0.18459813
# [TRAIN] epoch:  10 batch:  2 step:  150 loss:  0.15622356534004211 recon_detail loss:  tensor(0.1674, device='mps:0') kl loss:  tensor(33.0188, device='mps:0')
# vmin -0.184774 vmax -0.18461731
# [TRAIN] epoch:  10 batch:  3 step:  200 loss:  0.17982670664787292 recon_detail loss:  tensor(0.2001, device='mps:0') kl loss:  tensor(33.5309, device='mps:0')
# vmin -0.18542416 vmax -0.18378091
# [TRAIN] epoch:  10 batch:  3 step:  250 loss:  0.13102960586547852 recon_detail loss:  tensor(0.1341, device='mps:0') kl loss:  tensor(31.4607, device='mps:0')
# vmin -0.18541136 vmax -0.18375589
# [TRAIN] epoch:  10 batch:  4 step:  300 loss:  0.14229446649551392 recon_detail loss:  tensor(0.1495, device='mps:0') kl loss:  tensor(32.1077, device='mps:0')
# vmin -0.18522379 vmax -0.18390138
# [TRAIN] epoch:  10 batch:  5 step:  350 loss:  0.14419588446617126 recon_detail loss:  tensor(0.1503, device='mps:0') kl loss:  tensor(33.4003, device='mps:0')
# vmin -0.18501371 vmax -0.18452494
# [VALID] epoch:  10 batch:  0 step:  20 loss:  0.2045859545469284 kl loss:  tensor(32.5179, device='mps:0')
# vmin -0.18465199 vmax -0.18457991
# [VALID] epoch:  10 batch:  0 step:  40 loss:  0.19555768370628357 kl loss:  tensor(32.8208, device='mps:0')
# vmin -0.1846609 vmax -0.18454589
# [VALID] epoch:  10 batch:  0 step:  60 loss:  0.19994810223579407 kl loss:  tensor(32.6034, device='mps:0')
# vmin -0.18465784 vmax -0.18454885
# Epoch 11/1000, Train Loss: 1.510519e-01, Val Loss: 1.993579e-01
# [TRAIN] epoch:  11 batch:  0 step:  50 loss:  0.13495703041553497 recon_detail loss:  tensor(0.1388, device='mps:0') kl loss:  tensor(33.4693, device='mps:0')
# vmin -0.18956198 vmax -0.18003818
# [TRAIN] epoch:  11 batch:  1 step:  100 loss:  0.1375395804643631 recon_detail loss:  tensor(0.1459, device='mps:0') kl loss:  tensor(30.7981, device='mps:0')
# vmin -0.18484865 vmax -0.18440704
# [TRAIN] epoch:  11 batch:  2 step:  150 loss:  0.146234393119812 recon_detail loss:  tensor(0.1554, device='mps:0') kl loss:  tensor(31.8913, device='mps:0')
# vmin -0.1849389 vmax -0.18422897
# [TRAIN] epoch:  11 batch:  3 step:  200 loss:  0.17244258522987366 recon_detail loss:  tensor(0.1906, device='mps:0') kl loss:  tensor(33.6238, device='mps:0')
# vmin -0.1858214 vmax -0.18413603
# [TRAIN] epoch:  11 batch:  3 step:  250 loss:  0.1334729790687561 recon_detail loss:  tensor(0.1394, device='mps:0') kl loss:  tensor(31.4872, device='mps:0')
# vmin -0.1858214 vmax -0.18413603
# [TRAIN] epoch:  11 batch:  4 step:  300 loss:  0.13773418962955475 recon_detail loss:  tensor(0.1473, device='mps:0') kl loss:  tensor(30.8810, device='mps:0')
# vmin -0.18492669 vmax -0.18428336
# [TRAIN] epoch:  11 batch:  5 step:  350 loss:  0.13961473107337952 recon_detail loss:  tensor(0.1420, device='mps:0') kl loss:  tensor(33.9760, device='mps:0')
# vmin -0.18654762 vmax -0.18272822
# [VALID] epoch:  11 batch:  0 step:  20 loss:  0.20161743462085724 kl loss:  tensor(33.7456, device='mps:0')
# vmin -0.18464738 vmax -0.18458019
# [VALID] epoch:  11 batch:  0 step:  40 loss:  0.20009109377861023 kl loss:  tensor(32.7859, device='mps:0')
# vmin -0.1846609 vmax -0.18454589
# [VALID] epoch:  11 batch:  0 step:  60 loss:  0.19959284365177155 kl loss:  tensor(33.6429, device='mps:0')
# vmin -0.18464738 vmax -0.18458019
# Epoch 12/1000, Train Loss: 1.448912e-01, Val Loss: 1.949009e-01
# [TRAIN] epoch:  12 batch:  0 step:  50 loss:  0.13171938061714172 recon_detail loss:  tensor(0.1378, device='mps:0') kl loss:  tensor(31.4031, device='mps:0')
# vmin -0.18735576 vmax -0.18194686
# [TRAIN] epoch:  12 batch:  1 step:  100 loss:  0.13741947710514069 recon_detail loss:  tensor(0.1473, device='mps:0') kl loss:  tensor(30.6136, device='mps:0')
# vmin -0.18474236 vmax -0.18454012
# [TRAIN] epoch:  12 batch:  2 step:  150 loss:  0.15064966678619385 recon_detail loss:  tensor(0.1638, device='mps:0') kl loss:  tensor(30.7872, device='mps:0')
# vmin -0.18474926 vmax -0.18443583
# [TRAIN] epoch:  12 batch:  3 step:  200 loss:  0.1667061299085617 recon_detail loss:  tensor(0.1805, device='mps:0') kl loss:  tensor(34.6543, device='mps:0')
# vmin -0.18513507 vmax -0.18402614
# [TRAIN] epoch:  12 batch:  3 step:  250 loss:  0.1374644637107849 recon_detail loss:  tensor(0.1500, device='mps:0') kl loss:  tensor(30.6659, device='mps:0')
# vmin -0.18518147 vmax -0.18419911
# [TRAIN] epoch:  12 batch:  4 step:  300 loss:  0.12171173095703125 recon_detail loss:  tensor(0.1257, device='mps:0') kl loss:  tensor(28.6594, device='mps:0')
# vmin -0.18460429 vmax -0.18458958
# [TRAIN] epoch:  12 batch:  5 step:  350 loss:  0.1345846801996231 recon_detail loss:  tensor(0.1420, device='mps:0') kl loss:  tensor(31.1464, device='mps:0')
# vmin -0.18950024 vmax -0.17994946
# [VALID] epoch:  12 batch:  0 step:  20 loss:  0.20219048857688904 kl loss:  tensor(33.2952, device='mps:0')
# vmin -0.1846609 vmax -0.18454589
# [VALID] epoch:  12 batch:  0 step:  40 loss:  0.1980292797088623 kl loss:  tensor(32.8261, device='mps:0')
# vmin -0.18466595 vmax -0.18454541
# [VALID] epoch:  12 batch:  0 step:  60 loss:  0.20348061621189117 kl loss:  tensor(32.9335, device='mps:0')
# vmin -0.18464738 vmax -0.18458019
# Epoch 13/1000, Train Loss: 1.404643e-01, Val Loss: 1.992107e-01
# [TRAIN] epoch:  13 batch:  0 step:  50 loss:  0.12513917684555054 recon_detail loss:  tensor(0.1319, device='mps:0') kl loss:  tensor(28.7905, device='mps:0')
# vmin -0.18493855 vmax -0.1843214
# [TRAIN] epoch:  13 batch:  1 step:  100 loss:  0.12401926517486572 recon_detail loss:  tensor(0.1251, device='mps:0') kl loss:  tensor(31.5610, device='mps:0')
# vmin -0.18532923 vmax -0.18378717
# [TRAIN] epoch:  13 batch:  2 step:  150 loss:  0.13981105387210846 recon_detail loss:  tensor(0.1469, device='mps:0') kl loss:  tensor(31.8773, device='mps:0')
# vmin -0.18532465 vmax -0.18395442
# [TRAIN] epoch:  13 batch:  3 step:  200 loss:  0.15448540449142456 recon_detail loss:  tensor(0.1623, device='mps:0') kl loss:  tensor(33.9861, device='mps:0')
# vmin -0.18776703 vmax -0.1820099
# [TRAIN] epoch:  13 batch:  3 step:  250 loss:  0.1203794926404953 recon_detail loss:  tensor(0.1205, device='mps:0') kl loss:  tensor(32.1809, device='mps:0')
# vmin -0.18795912 vmax -0.18207286
# [TRAIN] epoch:  13 batch:  4 step:  300 loss:  0.1309152990579605 recon_detail loss:  tensor(0.1390, device='mps:0') kl loss:  tensor(29.0652, device='mps:0')
# vmin -0.18578371 vmax -0.18343616
# [TRAIN] epoch:  13 batch:  5 step:  350 loss:  0.13357658684253693 recon_detail loss:  tensor(0.1339, device='mps:0') kl loss:  tensor(35.8012, device='mps:0')
# vmin -0.1848426 vmax -0.18437621
# [VALID] epoch:  13 batch:  0 step:  20 loss:  0.1860012412071228 kl loss:  tensor(29.1929, device='mps:0')
# vmin -0.1846668 vmax -0.184548
# [VALID] epoch:  13 batch:  0 step:  40 loss:  0.19567526876926422 kl loss:  tensor(28.8946, device='mps:0')
# vmin -0.1846609 vmax -0.18454589
# [VALID] epoch:  13 batch:  0 step:  60 loss:  0.20762358605861664 kl loss:  tensor(29.1102, device='mps:0')
# vmin -0.18465154 vmax -0.1845526
# Epoch 14/1000, Train Loss: 1.378215e-01, Val Loss: 1.940560e-01
# [TRAIN] epoch:  14 batch:  0 step:  50 loss:  0.1251985728740692 recon_detail loss:  tensor(0.1319, device='mps:0') kl loss:  tensor(30.3333, device='mps:0')
# vmin -0.18495935 vmax -0.18426594
# [TRAIN] epoch:  14 batch:  1 step:  100 loss:  0.1346130073070526 recon_detail loss:  tensor(0.1409, device='mps:0') kl loss:  tensor(32.7989, device='mps:0')
# vmin -0.18475065 vmax -0.18456501
# [TRAIN] epoch:  14 batch:  2 step:  150 loss:  0.13497842848300934 recon_detail loss:  tensor(0.1389, device='mps:0') kl loss:  tensor(31.8720, device='mps:0')
# vmin -0.184843 vmax -0.18428287
# [TRAIN] epoch:  14 batch:  3 step:  200 loss:  0.1551210880279541 recon_detail loss:  tensor(0.1657, device='mps:0') kl loss:  tensor(32.0259, device='mps:0')
# vmin -0.1846441 vmax -0.18455917
# [TRAIN] epoch:  14 batch:  3 step:  250 loss:  0.12328312546014786 recon_detail loss:  tensor(0.1274, device='mps:0') kl loss:  tensor(30.7036, device='mps:0')
# vmin -0.18465035 vmax -0.1845582
# [TRAIN] epoch:  14 batch:  4 step:  300 loss:  0.12238091975450516 recon_detail loss:  tensor(0.1305, device='mps:0') kl loss:  tensor(27.2378, device='mps:0')
# vmin -0.18545057 vmax -0.18471207
# [TRAIN] epoch:  14 batch:  5 step:  350 loss:  0.13257725536823273 recon_detail loss:  tensor(0.1354, device='mps:0') kl loss:  tensor(34.5438, device='mps:0')
# vmin -0.1878869 vmax -0.18041436
# [VALID] epoch:  14 batch:  0 step:  20 loss:  0.192440465092659 kl loss:  tensor(32.1718, device='mps:0')
# vmin -0.18464825 vmax -0.18455929
# [VALID] epoch:  14 batch:  0 step:  40 loss:  0.1933257281780243 kl loss:  tensor(32.9747, device='mps:0')
# vmin -0.1846668 vmax -0.184548
# [VALID] epoch:  14 batch:  0 step:  60 loss:  0.18784910440444946 kl loss:  tensor(32.1848, device='mps:0')
# vmin -0.18465154 vmax -0.1845526
# Epoch 15/1000, Train Loss: 1.341954e-01, Val Loss: 1.956526e-01
# [TRAIN] epoch:  15 batch:  0 step:  50 loss:  0.11785320937633514 recon_detail loss:  tensor(0.1212, device='mps:0') kl loss:  tensor(29.8180, device='mps:0')
# vmin -0.18473983 vmax -0.18449648
# [TRAIN] epoch:  15 batch:  1 step:  100 loss:  0.1272728443145752 recon_detail loss:  tensor(0.1328, device='mps:0') kl loss:  tensor(31.4943, device='mps:0')
# vmin -0.18486165 vmax -0.18416502
# [TRAIN] epoch:  15 batch:  2 step:  150 loss:  0.13235439360141754 recon_detail loss:  tensor(0.1369, device='mps:0') kl loss:  tensor(30.4157, device='mps:0')
# vmin -0.18563 vmax -0.18372037
# [TRAIN] epoch:  15 batch:  3 step:  200 loss:  0.15401071310043335 recon_detail loss:  tensor(0.1690, device='mps:0') kl loss:  tensor(29.3997, device='mps:0')
# vmin -0.1849993 vmax -0.18453221
# [TRAIN] epoch:  15 batch:  3 step:  250 loss:  0.12050031125545502 recon_detail loss:  tensor(0.1240, device='mps:0') kl loss:  tensor(30.7414, device='mps:0')
# vmin -0.18497758 vmax -0.18451604
# [TRAIN] epoch:  15 batch:  4 step:  300 loss:  0.12508727610111237 recon_detail loss:  tensor(0.1301, device='mps:0') kl loss:  tensor(31.0702, device='mps:0')
# vmin -0.19588387 vmax -0.17372017
# [TRAIN] epoch:  15 batch:  5 step:  350 loss:  0.1220073327422142 recon_detail loss:  tensor(0.1249, device='mps:0') kl loss:  tensor(30.1555, device='mps:0')
# vmin -0.18554579 vmax -0.18395393
# [VALID] epoch:  15 batch:  0 step:  20 loss:  0.1935746669769287 kl loss:  tensor(30.5924, device='mps:0')
# vmin -0.18464461 vmax -0.18457964
# [VALID] epoch:  15 batch:  0 step:  40 loss:  0.19652780890464783 kl loss:  tensor(30.2799, device='mps:0')
# vmin -0.1846668 vmax -0.184548
# [VALID] epoch:  15 batch:  0 step:  60 loss:  0.19734688103199005 kl loss:  tensor(30.7744, device='mps:0')
# vmin -0.1846427 vmax -0.18456791
# Epoch 16/1000, Train Loss: 1.332668e-01, Val Loss: 1.933247e-01
# [TRAIN] epoch:  16 batch:  0 step:  50 loss:  0.11806124448776245 recon_detail loss:  tensor(0.1194, device='mps:0') kl loss:  tensor(31.4260, device='mps:0')
# vmin -0.18523064 vmax -0.18410423
# [TRAIN] epoch:  16 batch:  1 step:  100 loss:  0.11324729025363922 recon_detail loss:  tensor(0.1146, device='mps:0') kl loss:  tensor(28.6535, device='mps:0')
# vmin -0.18804342 vmax -0.18054995
# [TRAIN] epoch:  16 batch:  2 step:  150 loss:  0.12974658608436584 recon_detail loss:  tensor(0.1356, device='mps:0') kl loss:  tensor(29.7738, device='mps:0')
# vmin -0.1848161 vmax -0.18435986
# [TRAIN] epoch:  16 batch:  3 step:  200 loss:  0.15239682793617249 recon_detail loss:  tensor(0.1643, device='mps:0') kl loss:  tensor(31.8966, device='mps:0')
# vmin -0.18501267 vmax -0.18435648
# [TRAIN] epoch:  16 batch:  3 step:  250 loss:  0.1135193482041359 recon_detail loss:  tensor(0.1175, device='mps:0') kl loss:  tensor(29.2000, device='mps:0')
# vmin -0.18501271 vmax -0.18436359
# [TRAIN] epoch:  16 batch:  4 step:  300 loss:  0.11793747544288635 recon_detail loss:  tensor(0.1213, device='mps:0') kl loss:  tensor(28.3115, device='mps:0')
# vmin -0.18520044 vmax -0.18398441
# [TRAIN] epoch:  16 batch:  5 step:  350 loss:  0.12780386209487915 recon_detail loss:  tensor(0.1292, device='mps:0') kl loss:  tensor(34.0443, device='mps:0')
# vmin -0.18551123 vmax -0.1839392
# [VALID] epoch:  16 batch:  0 step:  20 loss:  0.20030952990055084 kl loss:  tensor(29.1870, device='mps:0')
# vmin -0.18463953 vmax -0.184577
# [VALID] epoch:  16 batch:  0 step:  40 loss:  0.19054186344146729 kl loss:  tensor(28.7792, device='mps:0')
# vmin -0.18464461 vmax -0.18457964
# [VALID] epoch:  16 batch:  0 step:  60 loss:  0.19545646011829376 kl loss:  tensor(28.9889, device='mps:0')
# vmin -0.18464825 vmax -0.18455929
# Epoch 17/1000, Train Loss: 1.300075e-01, Val Loss: 1.956819e-01
# [TRAIN] epoch:  17 batch:  0 step:  50 loss:  0.1107829138636589 recon_detail loss:  tensor(0.1127, device='mps:0') kl loss:  tensor(28.5574, device='mps:0')
# vmin -0.18475996 vmax -0.18445346
# [TRAIN] epoch:  17 batch:  1 step:  100 loss:  0.12039735168218613 recon_detail loss:  tensor(0.1257, device='mps:0') kl loss:  tensor(29.7850, device='mps:0')
# vmin -0.18480653 vmax -0.18445201
# [TRAIN] epoch:  17 batch:  2 step:  150 loss:  0.13269264996051788 recon_detail loss:  tensor(0.1387, device='mps:0') kl loss:  tensor(31.1693, device='mps:0')
# vmin -0.18558657 vmax -0.18375263
# [TRAIN] epoch:  17 batch:  3 step:  200 loss:  0.1479140818119049 recon_detail loss:  tensor(0.1542, device='mps:0') kl loss:  tensor(33.9986, device='mps:0')
# vmin -0.18464787 vmax -0.18455276
# [TRAIN] epoch:  17 batch:  3 step:  250 loss:  0.11094234138727188 recon_detail loss:  tensor(0.1087, device='mps:0') kl loss:  tensor(31.4144, device='mps:0')
# vmin -0.18467373 vmax -0.18457232
# [TRAIN] epoch:  17 batch:  4 step:  300 loss:  0.12015683203935623 recon_detail loss:  tensor(0.1224, device='mps:0') kl loss:  tensor(31.2361, device='mps:0')
# vmin -0.18479237 vmax -0.18448429
# [TRAIN] epoch:  17 batch:  5 step:  350 loss:  0.12747670710086823 recon_detail loss:  tensor(0.1312, device='mps:0') kl loss:  tensor(31.5784, device='mps:0')
# vmin -0.18483664 vmax -0.1843033
# [VALID] epoch:  17 batch:  0 step:  20 loss:  0.19256114959716797 kl loss:  tensor(30.6211, device='mps:0')
# vmin -0.18463898 vmax -0.18457314
# [VALID] epoch:  17 batch:  0 step:  40 loss:  0.19749705493450165 kl loss:  tensor(30.8058, device='mps:0')
# vmin -0.1846427 vmax -0.18456791
# [VALID] epoch:  17 batch:  0 step:  60 loss:  0.2001943439245224 kl loss:  tensor(30.8357, device='mps:0')
# vmin -0.1846668 vmax -0.184548
# Epoch 18/1000, Train Loss: 1.283858e-01, Val Loss: 1.958182e-01
# [TRAIN] epoch:  18 batch:  0 step:  50 loss:  0.11119852215051651 recon_detail loss:  tensor(0.1123, device='mps:0') kl loss:  tensor(29.9128, device='mps:0')
# vmin -0.18477856 vmax -0.18440296
# [TRAIN] epoch:  18 batch:  1 step:  100 loss:  0.12721535563468933 recon_detail loss:  tensor(0.1353, device='mps:0') kl loss:  tensor(30.0724, device='mps:0')
# vmin -0.1848238 vmax -0.1843698
# [TRAIN] epoch:  18 batch:  2 step:  150 loss:  0.1262696385383606 recon_detail loss:  tensor(0.1314, device='mps:0') kl loss:  tensor(30.3817, device='mps:0')
# vmin -0.18568891 vmax -0.1834253
# [TRAIN] epoch:  18 batch:  3 step:  200 loss:  0.1437118947505951 recon_detail loss:  tensor(0.1454, device='mps:0') kl loss:  tensor(34.9735, device='mps:0')
# vmin -0.18474424 vmax -0.18451932
# [TRAIN] epoch:  18 batch:  3 step:  250 loss:  0.11223142594099045 recon_detail loss:  tensor(0.1156, device='mps:0') kl loss:  tensor(29.1266, device='mps:0')
# vmin -0.18468262 vmax -0.18448842
# [TRAIN] epoch:  18 batch:  4 step:  300 loss:  0.10928061604499817 recon_detail loss:  tensor(0.1128, device='mps:0') kl loss:  tensor(26.4795, device='mps:0')
# vmin -0.42148045 vmax 0.034087535
# [TRAIN] epoch:  18 batch:  5 step:  350 loss:  0.11925873160362244 recon_detail loss:  tensor(0.1232, device='mps:0') kl loss:  tensor(29.5024, device='mps:0')
# vmin -0.18472835 vmax -0.18444198
# [VALID] epoch:  18 batch:  0 step:  20 loss:  0.19943448901176453 kl loss:  tensor(32.0470, device='mps:0')
# vmin -0.18465154 vmax -0.1845526
# [VALID] epoch:  18 batch:  0 step:  40 loss:  0.20341862738132477 kl loss:  tensor(32.1647, device='mps:0')
# vmin -0.18466386 vmax -0.1845452
# [VALID] epoch:  18 batch:  0 step:  60 loss:  0.2036290168762207 kl loss:  tensor(31.6692, device='mps:0')
# vmin -0.18464683 vmax -0.18456271
# Epoch 19/1000, Train Loss: 1.255972e-01, Val Loss: 1.980001e-01
# [TRAIN] epoch:  19 batch:  0 step:  50 loss:  0.11333956569433212 recon_detail loss:  tensor(0.1181, device='mps:0') kl loss:  tensor(28.4474, device='mps:0')
# vmin -0.18548036 vmax -0.18394428
# [TRAIN] epoch:  19 batch:  1 step:  100 loss:  0.12270918488502502 recon_detail loss:  tensor(0.1274, device='mps:0') kl loss:  tensor(30.8643, device='mps:0')
# vmin -0.18500166 vmax -0.18416676
# [TRAIN] epoch:  19 batch:  2 step:  150 loss:  0.1226993054151535 recon_detail loss:  tensor(0.1286, device='mps:0') kl loss:  tensor(29.1864, device='mps:0')
# vmin -0.18532479 vmax -0.18378614
# [TRAIN] epoch:  19 batch:  3 step:  200 loss:  0.1472921520471573 recon_detail loss:  tensor(0.1562, device='mps:0') kl loss:  tensor(31.9550, device='mps:0')
# vmin -0.20597287 vmax -0.16228311
# [TRAIN] epoch:  19 batch:  3 step:  250 loss:  0.10361668467521667 recon_detail loss:  tensor(0.0980, device='mps:0') kl loss:  tensor(31.6213, device='mps:0')
# vmin -0.20597659 vmax -0.1622542
# [TRAIN] epoch:  19 batch:  4 step:  300 loss:  0.1136506050825119 recon_detail loss:  tensor(0.1162, device='mps:0') kl loss:  tensor(29.0166, device='mps:0')
# vmin -0.18482865 vmax -0.1843113
# [TRAIN] epoch:  19 batch:  5 step:  350 loss:  0.12035778909921646 recon_detail loss:  tensor(0.1280, device='mps:0') kl loss:  tensor(28.8191, device='mps:0')
# vmin -0.1853709 vmax -0.1838665
# [VALID] epoch:  19 batch:  0 step:  20 loss:  0.20096896588802338 kl loss:  tensor(28.8061, device='mps:0')
# vmin -0.1846427 vmax -0.18456791
# [VALID] epoch:  19 batch:  0 step:  40 loss:  0.18794268369674683 kl loss:  tensor(29.2355, device='mps:0')
# vmin -0.18465053 vmax -0.18457967
# [VALID] epoch:  19 batch:  0 step:  60 loss:  0.19388717412948608 kl loss:  tensor(29.6271, device='mps:0')
# vmin -0.18464936 vmax -0.18455409
# Epoch 20/1000, Train Loss: 1.245250e-01, Val Loss: 1.931021e-01
# [TRAIN] epoch:  20 batch:  0 step:  50 loss:  0.10672688484191895 recon_detail loss:  tensor(0.1079, device='mps:0') kl loss:  tensor(28.7872, device='mps:0')
# vmin -0.18503408 vmax -0.184244
# [TRAIN] epoch:  20 batch:  1 step:  100 loss:  0.1157340258359909 recon_detail loss:  tensor(0.1236, device='mps:0') kl loss:  tensor(26.7980, device='mps:0')
# vmin -0.18489572 vmax -0.1833147
# [TRAIN] epoch:  20 batch:  2 step:  150 loss:  0.11731407791376114 recon_detail loss:  tensor(0.1178, device='mps:0') kl loss:  tensor(30.2292, device='mps:0')
# vmin -0.18476698 vmax -0.18456599
# [TRAIN] epoch:  20 batch:  3 step:  200 loss:  0.14109939336776733 recon_detail loss:  tensor(0.1458, device='mps:0') kl loss:  tensor(32.7822, device='mps:0')
# vmin -0.185062 vmax -0.18415649
# [TRAIN] epoch:  20 batch:  3 step:  250 loss:  0.11008670181035995 recon_detail loss:  tensor(0.1163, device='mps:0') kl loss:  tensor(26.9181, device='mps:0')
# vmin -0.18504143 vmax -0.1841271
# [TRAIN] epoch:  20 batch:  4 step:  300 loss:  0.12498597800731659 recon_detail loss:  tensor(0.1327, device='mps:0') kl loss:  tensor(30.5793, device='mps:0')
# vmin -0.18481842 vmax -0.1844146
# [TRAIN] epoch:  20 batch:  5 step:  350 loss:  0.12248525023460388 recon_detail loss:  tensor(0.1302, device='mps:0') kl loss:  tensor(29.0609, device='mps:0')
# vmin -0.18546025 vmax -0.18392564
# [VALID] epoch:  20 batch:  0 step:  20 loss:  0.19967886805534363 kl loss:  tensor(29.8258, device='mps:0')
# vmin -0.18463898 vmax -0.18457314
# [VALID] epoch:  20 batch:  0 step:  40 loss:  0.20118942856788635 kl loss:  tensor(28.8862, device='mps:0')
# vmin -0.18463953 vmax -0.184577
# [VALID] epoch:  20 batch:  0 step:  60 loss:  0.20227859914302826 kl loss:  tensor(29.1209, device='mps:0')
# vmin -0.18465438 vmax -0.18455039
# Epoch 21/1000, Train Loss: 1.224518e-01, Val Loss: 1.980197e-01
# [TRAIN] epoch:  21 batch:  0 step:  50 loss:  0.11307205259799957 recon_detail loss:  tensor(0.1150, device='mps:0') kl loss:  tensor(30.9942, device='mps:0')
# vmin -0.1846639 vmax -0.18458143
# [TRAIN] epoch:  21 batch:  1 step:  100 loss:  0.1105816587805748 recon_detail loss:  tensor(0.1137, device='mps:0') kl loss:  tensor(28.4289, device='mps:0')
# vmin -0.19049542 vmax -0.18009499
# [TRAIN] epoch:  21 batch:  2 step:  150 loss:  0.12789538502693176 recon_detail loss:  tensor(0.1334, device='mps:0') kl loss:  tensor(31.0305, device='mps:0')
# vmin -0.18476819 vmax -0.18437587
# [TRAIN] epoch:  21 batch:  3 step:  200 loss:  0.13627195358276367 recon_detail loss:  tensor(0.1419, device='mps:0') kl loss:  tensor(30.5986, device='mps:0')
# vmin -0.18490922 vmax -0.18435216
# [TRAIN] epoch:  21 batch:  3 step:  250 loss:  0.10451323539018631 recon_detail loss:  tensor(0.1046, device='mps:0') kl loss:  tensor(28.2820, device='mps:0')
# vmin -0.18491516 vmax -0.1843285
# [TRAIN] epoch:  21 batch:  4 step:  300 loss:  0.11014105379581451 recon_detail loss:  tensor(0.1108, device='mps:0') kl loss:  tensor(29.9318, device='mps:0')
# vmin -0.1855913 vmax -0.18377608
# [TRAIN] epoch:  21 batch:  5 step:  350 loss:  0.09974688291549683 recon_detail loss:  tensor(0.0948, device='mps:0') kl loss:  tensor(30.1257, device='mps:0')
# vmin -0.18470488 vmax -0.18451539
# [VALID] epoch:  21 batch:  0 step:  20 loss:  0.1991206705570221 kl loss:  tensor(29.3437, device='mps:0')
# vmin -0.18464461 vmax -0.18457964
# [VALID] epoch:  21 batch:  0 step:  40 loss:  0.2048291265964508 kl loss:  tensor(29.0702, device='mps:0')
# vmin -0.18464936 vmax -0.18455409
# [VALID] epoch:  21 batch:  0 step:  60 loss:  0.19998770952224731 kl loss:  tensor(29.3904, device='mps:0')
# vmin -0.18464738 vmax -0.18458019
# Epoch 22/1000, Train Loss: 1.203186e-01, Val Loss: 1.977171e-01
# [TRAIN] epoch:  22 batch:  0 step:  50 loss:  0.10686876624822617 recon_detail loss:  tensor(0.1062, device='mps:0') kl loss:  tensor(30.2683, device='mps:0')
# vmin -0.18923025 vmax -0.18019119
# [TRAIN] epoch:  22 batch:  1 step:  100 loss:  0.10984955728054047 recon_detail loss:  tensor(0.1141, device='mps:0') kl loss:  tensor(27.5571, device='mps:0')
# vmin -0.18596849 vmax -0.18304262
# [TRAIN] epoch:  22 batch:  2 step:  150 loss:  0.11750545352697372 recon_detail loss:  tensor(0.1167, device='mps:0') kl loss:  tensor(31.7967, device='mps:0')
# vmin -0.18529713 vmax -0.18376169
# [TRAIN] epoch:  22 batch:  3 step:  200 loss:  0.14288921654224396 recon_detail loss:  tensor(0.1438, device='mps:0') kl loss:  tensor(34.7185, device='mps:0')
# vmin -0.19453621 vmax -0.17602691
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 277
#     274         json.dump(model_param, f, indent=2)
#     276 if __name__ == "__main__":
# --> 277     main()
#
# Cell In[2], line 250, in main()
#     248 for epoch in range(model_param['num_epochs']):
#     249     epoch=epoch+7
# --> 250     train_loss = train_one_epoch(model, train_loader, device, optimizer,model_param,epoch)
#     251     val_loss = eval_one_epoch(model, val_loader, device,model_param,epoch)
#     252     loss_dict[epoch] = {'train_loss':train_loss, 'val_loss':val_loss}
#
# Cell In[2], line 171, in train_one_epoch(model, loader, device, opt, model_param, epoch)
#     169 opt.zero_grad()
#     170 loss.backward()
# --> 171 opt.step()
#     172 total += float(loss.item())
#     173 count+=1
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/general/lib/python3.11/site-packages/torch/optim/optimizer.py:373, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     368         else:
#     369             raise RuntimeError(
#     370                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     371             )
# --> 373 out = func(*args, **kwargs)
#     374 self._optimizer_step_code()
#     376 # call optimizer step post hooks
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/general/lib/python3.11/site-packages/torch/optim/optimizer.py:76, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      74     torch.set_grad_enabled(self.defaults['differentiable'])
#      75     torch._dynamo.graph_break()
# ---> 76     ret = func(self, *args, **kwargs)
#      77 finally:
#      78     torch._dynamo.graph_break()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/general/lib/python3.11/site-packages/torch/optim/adam.py:163, in Adam.step(self, closure)
#     152     beta1, beta2 = group['betas']
#     154     self._init_group(
#     155         group,
#     156         params_with_grad,
#    (...)
#     160         max_exp_avg_sqs,
#     161         state_steps)
# --> 163     adam(
#     164         params_with_grad,
#     165         grads,
#     166         exp_avgs,
#     167         exp_avg_sqs,
#     168         max_exp_avg_sqs,
#     169         state_steps,
#     170         amsgrad=group['amsgrad'],
#     171         beta1=beta1,
#     172         beta2=beta2,
#     173         lr=group['lr'],
#     174         weight_decay=group['weight_decay'],
#     175         eps=group['eps'],
#     176         maximize=group['maximize'],
#     177         foreach=group['foreach'],
#     178         capturable=group['capturable'],
#     179         differentiable=group['differentiable'],
#     180         fused=group['fused'],
#     181         grad_scale=getattr(self, "grad_scale", None),
#     182         found_inf=getattr(self, "found_inf", None),
#     183     )
#     185 return loss
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/general/lib/python3.11/site-packages/torch/optim/adam.py:311, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     308 else:
#     309     func = _single_tensor_adam
# --> 311 func(params,
#     312      grads,
#     313      exp_avgs,
#     314      exp_avg_sqs,
#     315      max_exp_avg_sqs,
#     316      state_steps,
#     317      amsgrad=amsgrad,
#     318      beta1=beta1,
#     319      beta2=beta2,
#     320      lr=lr,
#     321      weight_decay=weight_decay,
#     322      eps=eps,
#     323      maximize=maximize,
#     324      capturable=capturable,
#     325      differentiable=differentiable,
#     326      grad_scale=grad_scale,
#     327      found_inf=found_inf)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/general/lib/python3.11/site-packages/torch/optim/adam.py:432, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     430         denom = (max_exp_avg_sqs[i].sqrt() / bias_correction2_sqrt).add_(eps)
#     431     else:
# --> 432         denom = (exp_avg_sq.sqrt() / bias_correction2_sqrt).add_(eps)
#     434     param.addcdiv_(exp_avg, denom, value=-step_size)
#     436 # Lastly, switch back to complex view
#
# KeyboardInterrupt:
