# %%
import torch
import torch.nn.functional as F
from fem_dataset_to_image_full_mesh_diffusion import FemImageDataset as MeshDataset
from fem_model import ScalingVAE3
import json
from torch.utils.data import DataLoader
from utils import EarlyStopping
import gc
import numpy as np
import matplotlib.pyplot as plt


early_stopping = EarlyStopping(
    patience=50,     # FEM/GNN은 15~30 권장
    min_delta=1e-6,  # loss 스케일에 맞게
    mode="min"
)
def collate_flatten(batch): 
    images, conds = [], [] 
    batch_size=len(batch) 
    step_num_in_batch=len(batch[0]["image"]) 
    idxs=[] 
    for i in range(batch_size): 
        idx = torch.randperm(len(batch[0]["image"])) 
        idxs.append(idx) 
        # print(batch[i]['min_max'])
    idxs=np.array(idxs).T 

    for i in range(step_num_in_batch): 
        batch_images=[] 
        batch_conds=[] 
        for b_i,b in enumerate(batch): 
            id=idxs[i][b_i] 
            batch_images.append(b['image'][id]) 
            batch_conds.append(b['cond'][id]) 
        images.append(batch_images) 
        conds.append(batch_conds) 
    return { "image": images, "cond": conds, }

def draw(data1,data2,model_param): 
    stride=1 
    clip_q=(0.25,0.75) 
    cmap="jet" 
    ql, qh = np.quantile(data1.cpu().detach().numpy(), clip_q) 
    Uf1_clip = np.clip(data1.cpu().detach().numpy(), ql, qh) 
    ql, qh = np.quantile(data2.cpu().detach().numpy(), clip_q) 
    Uf2_clip = np.clip(data2.cpu().detach().numpy(), ql, qh) 
    print('vmin',Uf1_clip.min(),'vmax',Uf1_clip.max())
    plt.figure(figsize=(8, 4)) 
    plt.subplot(1, 3, 1) 
    plt.imshow(Uf1_clip, cmap="gray",vmin=Uf1_clip.min(),vmax=Uf1_clip.max()) 
    plt.title("Image 1") 
    plt.axis("off") 
    plt.subplot(1, 3, 2) 
    plt.imshow(Uf2_clip, cmap="gray",vmin=Uf1_clip.min(),vmax=Uf1_clip.max())
    plt.title("Image 2") 
    plt.axis("off") 
    plt.subplot(1, 3, 3) 
    plt.imshow(np.abs(Uf1_clip-Uf2_clip), cmap="gray",vmin=Uf1_clip.min(),vmax=Uf1_clip.max())
    plt.title("Image 3") 
    plt.axis("off")
    plt.tight_layout() 
    plt.show()

def kl_divergence_gaussian(mu, logvar, clamp=(-1, 1)):
    """
    KL( N(mu, var) || N(0, I) )
    Supports mu/logvar with shape:
      [B, Z] or [B, C, H, W] or [B, ...]
    """
    if clamp is not None:
        logvar = torch.clamp(logvar, min=clamp[0], max=clamp[1])

    # flatten all non-batch dimensions
    mu = mu.view(mu.size(0), -1)
    logvar = logvar.view(logvar.size(0), -1)

    kl = 0.5 * torch.sum(
        torch.exp(logvar) + mu**2 - 1.0 - logvar,
        dim=1
    )

    return kl.mean()

def charbonnier_loss(pred: torch.Tensor,
                     target: torch.Tensor,
                     eps: float = 1e-8,
                     reduction: str = "mean") -> torch.Tensor:
    """
    Charbonnier loss (a smooth L1 / pseudo-Huber variant):
        L = sqrt((pred - target)^2 + eps^2)

    Args:
        pred, target: same shape tensors
        eps: smoothing term (bigger -> more L1-like near 0)
        reduction: "mean" | "sum" | "none"

    Returns:
        loss tensor (scalar if reduced)
    """
    if pred.shape != target.shape:
        raise ValueError(f"Shape mismatch: pred{pred.shape} vs target{target.shape}")

    diff = pred - target
    loss = torch.sqrt(diff * diff + eps * eps)

    if reduction == "mean":
        return loss.mean()
    if reduction == "sum":
        return loss.sum()
    if reduction == "none":
        return loss
    raise ValueError("reduction must be one of {'mean','sum','none'}")




def GradientDifferenceLossCharbonnier( pred, target):
    grad_pred_x = pred[:, :, :, 1:] - pred[:, :, :, :-1]
    grad_target_x = target[:, :, :, 1:] - target[:, :, :, :-1]

    grad_pred_y = pred[:, :, 1:, :] - pred[:, :, :-1, :]
    grad_target_y = target[:, :, 1:, :] - target[:, :, :-1, :]

    return (
        charbonnier_loss(grad_pred_x, grad_target_x) +
        charbonnier_loss(grad_pred_y, grad_target_y)
    )

def cvae_loss(x, scaled_x_hat, x_hat, mu, logvar, beta=1e-3):
    mean = x.mean(dim=(1,2,3), keepdim=True) 
    std = x.std(dim=(1,2,3), keepdim=True) + 1e-12 
    x_norm=(x-mean)/std 
    recon = charbonnier_loss(x, x_hat) 
    recon_detail = charbonnier_loss(x_norm,scaled_x_hat)
    recon_detail_2 = GradientDifferenceLossCharbonnier(x_norm,scaled_x_hat)
    kl = kl_divergence_gaussian(mu, logvar) 

    return (1-beta)*(0.2*recon + 0.6*recon_detail + 0.2*recon_detail_2) + beta * kl, {"recon": recon.detach(),"recon_detail":recon_detail.detach(), "kl": kl.detach()}

def draw_latent(mu, logvar, clamp=(-1, 1)): 
    if clamp is not None: 
        logvar = torch.clamp(logvar, min=clamp[0], max=clamp[1]) 
        mu = mu.view(mu.size(0), -1) 
        logvar = logvar.view(logvar.size(0), -1) 
        plt.figure(figsize=(8, 4)) 
        plt.subplot(1, 2, 1) 
        plt.hist(mu.flatten().detach().cpu(), bins=100) 
        plt.subplot(1, 2, 2) 
        plt.hist(logvar.flatten().detach().cpu(), bins=100) 
        plt.title("Image 1") 
        plt.show()

def train_one_epoch(model, loader, device, opt, model_param,epoch): 
    model.train() 
    total = 0.0 
    count=0 
    beta_target=1e-1
    warmup_epochs=10 
    warm = min(1.0, (epoch + 1) / max(1, warmup_epochs)) 
    beta = beta_target * warm 
    for i, batch in enumerate(loader): 
        imags=batch['image'] 
        conds=batch['cond'] 
        for b in range(len(imags)): 
            s_batch = {'image':torch.stack(imags[b]).to(device),'cond':torch.Tensor(np.array(conds[b])).to(device)} 
            scaled_x_hat,x_hat, mu, logvar, _ = model(s_batch['image']) 
            loss, parts = cvae_loss(s_batch['image'], scaled_x_hat,x_hat, mu, logvar, beta=beta) 
            opt.zero_grad() 
            loss.backward() 
            opt.step() 
            total += float(loss.item())
            count+=1 
            if count % 50 == 0: 
                print('[TRAIN] epoch: ',epoch,'batch: ',i,'step: ',count,'loss: ',float(loss.item()),'recon_detail loss: ', parts['recon_detail'] ,'kl loss: ', parts['kl']) 
                origin_image=torch.stack(imags[b])[0,:][(model_param['in_channels']-1)//2] 
                pred_image=x_hat[0,:][(model_param['in_channels']-1)//2].cpu()
                draw_latent(mu, logvar, clamp=(-1, 1))
                draw(origin_image,pred_image,model_param) 
        del batch 
        gc.collect() 
    return total / max(1, count)
@torch.no_grad()
def eval_one_epoch(model, loader, device,  model_param,epoch):
    model.eval()
    total = 0.0 
    count=0 
    beta_target=1e-1
    warmup_epochs=10 
    warm = min(1.0, (epoch + 1) / max(1, warmup_epochs)) 
    beta = beta_target * warm 
    for i, batch in enumerate(loader): 
        imags=batch['image'] 
        conds=batch['cond'] 
        for b in range(len(imags)): 
            s_batch = {'image':torch.stack(imags[b]).to(device),'cond':torch.Tensor(np.array(conds[b])).to(device)} 
            scaled_x_hat,x_hat, mu, logvar, _ = model(s_batch['image']) 
            loss, parts = cvae_loss(s_batch['image'], scaled_x_hat,x_hat, mu, logvar, beta=beta) 
            total += float(loss.item())
            count+=1 
            if count % 20 == 0: 
                print('[VALID] epoch: ',epoch,'batch: ',i,'step: ',count,'loss: ',float(loss.item()),'kl loss: ', parts['kl']) 
                origin_image=torch.stack(imags[b])[0,:][(model_param['in_channels']-1)//2] 
                pred_image=x_hat[0,:][(model_param['in_channels']-1)//2].cpu()
                draw(origin_image,pred_image,model_param) 
        del batch 
        gc.collect() 
    return total / max(1, count)

def main():
    root = "./data"
    if torch.cuda.is_available() :
        device='cuda'
    elif torch.backends.mps.is_available() :
        device='mps'
    else :
        device='cpu'

    model_param={ 'in_channels':3, 
                'out_channels':3,
                'GRID':64,
                'loss_scale':1.0,
                'learning_rate':1e-3,
                'num_epochs':1000,
                'base':256,
                'latent_dim':256,
                'batch_size':128,
                'depth':4 } 
    
    train_ds = MeshDataset(root_dir=root,type='train',GRID=model_param['GRID'],in_channels=model_param['in_channels']) 
    val_ds= MeshDataset(root_dir=root,type='valid',GRID=model_param['GRID'],in_channels=model_param['in_channels']) 

    train_loader = DataLoader(train_ds, batch_size=model_param['batch_size'], shuffle=True, collate_fn=collate_flatten) 
    val_loader = DataLoader(val_ds, batch_size=model_param['batch_size'], shuffle=False, collate_fn=collate_flatten) 
    example = train_ds[0] 
    model_param['cond_dim']=len(example['cond'][0]) 
    model_param['dataset_scale_info']=train_ds.scale_info 

    model = ScalingVAE3( in_channels=model_param['in_channels'], 
                latent_dim=model_param['latent_dim'], 
                base=model_param['base'],
                depth=model_param['depth'] ).to(device)
    # ckpt = torch.load("mesh_invariant_diffustion_vae4_early.pt", map_location=device)
    # model.load_state_dict(ckpt)
    model.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=model_param['learning_rate'], weight_decay=1e-6)
    loss_dict={}
    for epoch in range(model_param['num_epochs']):        
        train_loss = train_one_epoch(model, train_loader, device, optimizer,model_param,epoch)
        val_loss = eval_one_epoch(model, val_loader, device,model_param,epoch)
        loss_dict[epoch] = {'train_loss':train_loss, 'val_loss':val_loss}   
        print(f"Epoch {epoch+1}/{model_param['num_epochs']}, Train Loss: {train_loss:.6e}, Val Loss: {val_loss:.6e}")  
        improved = early_stopping.step(val_loss)
        with open(f"loss_history_diffustion_vae4_1.json", "w", encoding="utf-8") as f:
            json.dump(loss_dict, f, indent=2)
        if improved:
            best_val = val_loss
            # print(eval_one_epoch_sample_mse(model, val_loader, device, sched))
            torch.save(model.state_dict(), f"mesh_invariant_diffustion_vae4_1_early_epoch{str(epoch).zfill(3)}.pt")  # best만 저장

            with open(f"model_param_diffustion_vae4_1_early.json", "w", encoding="utf-8") as f:
                json.dump(model_param, f, indent=2)
        if early_stopping.should_stop:
            print(
                f"\n Early stopping at epoch {epoch} "
                f"(best val = {best_val:.6e})"
            )
            break
        if epoch%10==0:
            torch.save(model.state_dict(), f"mesh_invariant_diffustion_vae4_1_epoch{str(epoch).zfill(3)}.pt")
    torch.save(model.state_dict(), "mesh_invariant_diffustion_vae4_1.pt")
    with open(f"model_param_diffusion_vae4_1.json", "w", encoding="utf-8") as f:
        json.dump(model_param, f, indent=2) 

if __name__ == "__main__":
    main()
# Out:
# 100%|██████████| 805/805 [00:05<00:00, 154.00it/s]
# Loading FEM graph dataset...
# Build Complete FEM graph dataset...
# 100%|██████████| 805/805 [00:05<00:00, 151.43it/s]
# Loading FEM graph dataset...
# Build Complete FEM graph dataset...
# [TRAIN] epoch:  0 batch:  0 step:  50 loss:  0.6595069169998169 recon_detail loss:  tensor(0.8064, device='mps:0') kl loss:  tensor(15.9159, device='mps:0')
# vmin -0.189318 vmax -0.17996833
# [TRAIN] epoch:  0 batch:  1 step:  100 loss:  0.522338330745697 recon_detail loss:  tensor(0.8066, device='mps:0') kl loss:  tensor(2.3098, device='mps:0')
# vmin -0.18525806 vmax -0.18386158
# [TRAIN] epoch:  0 batch:  2 step:  150 loss:  0.45347896218299866 recon_detail loss:  tensor(0.6326, device='mps:0') kl loss:  tensor(4.8584, device='mps:0')
# vmin -0.18482031 vmax -0.18440035
# [TRAIN] epoch:  0 batch:  3 step:  200 loss:  0.4199288487434387 recon_detail loss:  tensor(0.4963, device='mps:0') kl loss:  tensor(9.7817, device='mps:0')
# vmin -0.18566947 vmax -0.1841233
# [TRAIN] epoch:  0 batch:  3 step:  250 loss:  0.4172252118587494 recon_detail loss:  tensor(0.4473, device='mps:0') kl loss:  tensor(12.4848, device='mps:0')
# vmin -0.1852135 vmax -0.18328704
# [TRAIN] epoch:  0 batch:  4 step:  300 loss:  0.3558969497680664 recon_detail loss:  tensor(0.4179, device='mps:0') kl loss:  tensor(8.1481, device='mps:0')
# vmin -0.18505993 vmax -0.18385683
# [TRAIN] epoch:  0 batch:  5 step:  350 loss:  0.36759713292121887 recon_detail loss:  tensor(0.4229, device='mps:0') kl loss:  tensor(9.0260, device='mps:0')
# vmin -0.18480653 vmax -0.1844289
# [VALID] epoch:  0 batch:  0 step:  20 loss:  0.3647785782814026 kl loss:  tensor(8.6026, device='mps:0')
# vmin -0.1846609 vmax -0.18454589
# [VALID] epoch:  0 batch:  0 step:  40 loss:  0.3618099093437195 kl loss:  tensor(8.3885, device='mps:0')
# vmin -0.18466595 vmax -0.18454541
# [VALID] epoch:  0 batch:  0 step:  60 loss:  0.35814112424850464 kl loss:  tensor(8.6977, device='mps:0')
# vmin -0.18464738 vmax -0.18458019
# Epoch 1/1000, Train Loss: 8.010797e-01, Val Loss: 3.630689e-01
# [TRAIN] epoch:  1 batch:  0 step:  50 loss:  0.40950989723205566 recon_detail loss:  tensor(0.5101, device='mps:0') kl loss:  tensor(4.2188, device='mps:0')
# vmin -0.18511537 vmax -0.1840985
# [TRAIN] epoch:  1 batch:  1 step:  100 loss:  0.4211740791797638 recon_detail loss:  tensor(0.5196, device='mps:0') kl loss:  tensor(4.4881, device='mps:0')
# vmin -0.18523778 vmax -0.1820712
# [TRAIN] epoch:  1 batch:  2 step:  150 loss:  0.4227387309074402 recon_detail loss:  tensor(0.5062, device='mps:0') kl loss:  tensor(4.9254, device='mps:0')
# vmin -0.18484959 vmax -0.18448089
# [TRAIN] epoch:  1 batch:  3 step:  200 loss:  0.4319240152835846 recon_detail loss:  tensor(0.5316, device='mps:0') kl loss:  tensor(4.6289, device='mps:0')
# vmin -0.18464504 vmax -0.18456498
# [TRAIN] epoch:  1 batch:  3 step:  250 loss:  0.40236011147499084 recon_detail loss:  tensor(0.4847, device='mps:0') kl loss:  tensor(4.5442, device='mps:0')
# vmin -0.18462731 vmax -0.18453684
# [TRAIN] epoch:  1 batch:  4 step:  300 loss:  0.4100286662578583 recon_detail loss:  tensor(0.5130, device='mps:0') kl loss:  tensor(4.0911, device='mps:0')
# vmin -0.18931736 vmax -0.1793565
# [TRAIN] epoch:  1 batch:  5 step:  350 loss:  0.38233399391174316 recon_detail loss:  tensor(0.4550, device='mps:0') kl loss:  tensor(4.5349, device='mps:0')
# vmin -0.19736378 vmax -0.17078574
# [VALID] epoch:  1 batch:  0 step:  20 loss:  0.4055691659450531 kl loss:  tensor(4.3963, device='mps:0')
# vmin -0.18466386 vmax -0.1845452
# [VALID] epoch:  1 batch:  0 step:  40 loss:  0.4033188819885254 kl loss:  tensor(4.4737, device='mps:0')
# vmin -0.18464683 vmax -0.18456271
# [VALID] epoch:  1 batch:  0 step:  60 loss:  0.39821285009384155 kl loss:  tensor(4.4891, device='mps:0')
# vmin -0.18464683 vmax -0.18456271
# Epoch 2/1000, Train Loss: 4.097097e-01, Val Loss: 4.064320e-01
# [TRAIN] epoch:  2 batch:  0 step:  50 loss:  0.423798531293869 recon_detail loss:  tensor(0.5141, device='mps:0') kl loss:  tensor(3.3472, device='mps:0')
# vmin -0.18464556 vmax -0.18457372
# [TRAIN] epoch:  2 batch:  1 step:  100 loss:  0.4555371105670929 recon_detail loss:  tensor(0.5788, device='mps:0') kl loss:  tensor(3.1035, device='mps:0')
# vmin -0.18591945 vmax -0.18335336
# [TRAIN] epoch:  2 batch:  2 step:  150 loss:  0.42899107933044434 recon_detail loss:  tensor(0.5423, device='mps:0') kl loss:  tensor(2.9381, device='mps:0')
# vmin -0.18520497 vmax -0.18405679
# [TRAIN] epoch:  2 batch:  3 step:  200 loss:  0.43854212760925293 recon_detail loss:  tensor(0.5654, device='mps:0') kl loss:  tensor(2.7821, device='mps:0')
# vmin -0.18466532 vmax -0.18438959
# [TRAIN] epoch:  2 batch:  3 step:  250 loss:  0.4163696765899658 recon_detail loss:  tensor(0.5459, device='mps:0') kl loss:  tensor(2.4361, device='mps:0')
# vmin -0.18461952 vmax -0.18450503
# [TRAIN] epoch:  2 batch:  4 step:  300 loss:  0.44130900502204895 recon_detail loss:  tensor(0.5840, device='mps:0') kl loss:  tensor(2.5215, device='mps:0')
# vmin -0.18472594 vmax -0.1843227
# [TRAIN] epoch:  2 batch:  5 step:  350 loss:  0.4314512610435486 recon_detail loss:  tensor(0.5481, device='mps:0') kl loss:  tensor(2.9081, device='mps:0')
# vmin -0.1850542 vmax -0.18404098
# [VALID] epoch:  2 batch:  0 step:  20 loss:  0.42880749702453613 kl loss:  tensor(3.1197, device='mps:0')
# vmin -0.18464936 vmax -0.18455409
# [VALID] epoch:  2 batch:  0 step:  40 loss:  0.42482343316078186 kl loss:  tensor(3.1173, device='mps:0')
# vmin -0.18463953 vmax -0.184577
# [VALID] epoch:  2 batch:  0 step:  60 loss:  0.4380216598510742 kl loss:  tensor(3.1502, device='mps:0')
# vmin -0.18463898 vmax -0.18457314
# Epoch 3/1000, Train Loss: 4.279276e-01, Val Loss: 4.343983e-01
# [TRAIN] epoch:  3 batch:  0 step:  50 loss:  0.4485545754432678 recon_detail loss:  tensor(0.6027, device='mps:0') kl loss:  tensor(1.9104, device='mps:0')
# vmin -0.1849128 vmax -0.18429242
# [TRAIN] epoch:  3 batch:  1 step:  100 loss:  0.44788482785224915 recon_detail loss:  tensor(0.6051, device='mps:0') kl loss:  tensor(1.8503, device='mps:0')
# vmin -0.1873297 vmax -0.1820454
# [TRAIN] epoch:  3 batch:  2 step:  150 loss:  0.45335304737091064 recon_detail loss:  tensor(0.6416, device='mps:0') kl loss:  tensor(1.4752, device='mps:0')
# vmin -0.18485425 vmax -0.1841689
# [TRAIN] epoch:  3 batch:  3 step:  200 loss:  0.43350690603256226 recon_detail loss:  tensor(0.5729, device='mps:0') kl loss:  tensor(2.0038, device='mps:0')
# vmin -0.18478397 vmax -0.184739
# [TRAIN] epoch:  3 batch:  3 step:  250 loss:  0.4445263743400574 recon_detail loss:  tensor(0.5756, device='mps:0') kl loss:  tensor(2.2293, device='mps:0')
# vmin -0.18463627 vmax -0.18457842
# [TRAIN] epoch:  3 batch:  4 step:  300 loss:  0.4411584436893463 recon_detail loss:  tensor(0.5920, device='mps:0') kl loss:  tensor(1.8767, device='mps:0')
# vmin -0.18464905 vmax -0.1845736
# [TRAIN] epoch:  3 batch:  5 step:  350 loss:  0.42561066150665283 recon_detail loss:  tensor(0.5653, device='mps:0') kl loss:  tensor(1.8813, device='mps:0')
# vmin -0.18488997 vmax -0.18447426
# [VALID] epoch:  3 batch:  0 step:  20 loss:  0.44895532727241516 kl loss:  tensor(1.7616, device='mps:0')
# vmin -0.18465784 vmax -0.18454885
# [VALID] epoch:  3 batch:  0 step:  40 loss:  0.44231271743774414 kl loss:  tensor(1.7333, device='mps:0')
# vmin -0.18464683 vmax -0.18456271
# [VALID] epoch:  3 batch:  0 step:  60 loss:  0.4540168344974518 kl loss:  tensor(1.6936, device='mps:0')
# vmin -0.18464202 vmax -0.18457794
# Epoch 4/1000, Train Loss: 4.426759e-01, Val Loss: 4.466485e-01
# [TRAIN] epoch:  4 batch:  0 step:  50 loss:  0.43504825234413147 recon_detail loss:  tensor(0.6367, device='mps:0') kl loss:  tensor(0.9757, device='mps:0')
# vmin -0.18468265 vmax -0.18455262
# [TRAIN] epoch:  4 batch:  1 step:  100 loss:  0.4541035592556 recon_detail loss:  tensor(0.6580, device='mps:0') kl loss:  tensor(1.0839, device='mps:0')
# vmin -0.18468562 vmax -0.18445726
# [TRAIN] epoch:  4 batch:  2 step:  150 loss:  0.4433863162994385 recon_detail loss:  tensor(0.6224, device='mps:0') kl loss:  tensor(1.2830, device='mps:0')
# vmin -0.18470113 vmax -0.18457493
# [TRAIN] epoch:  4 batch:  3 step:  200 loss:  0.43873074650764465 recon_detail loss:  tensor(0.6038, device='mps:0') kl loss:  tensor(1.4272, device='mps:0')
# vmin -0.18463391 vmax -0.18457069
# [TRAIN] epoch:  4 batch:  3 step:  250 loss:  0.4521106779575348 recon_detail loss:  tensor(0.6194, device='mps:0') kl loss:  tensor(1.5194, device='mps:0')
# vmin -0.1846401 vmax -0.18459702
# [TRAIN] epoch:  4 batch:  4 step:  300 loss:  0.45395180583000183 recon_detail loss:  tensor(0.6431, device='mps:0') kl loss:  tensor(1.2538, device='mps:0')
# vmin -0.1865179 vmax -0.18267778
# [TRAIN] epoch:  4 batch:  5 step:  350 loss:  0.4351692199707031 recon_detail loss:  tensor(0.6050, device='mps:0') kl loss:  tensor(1.3529, device='mps:0')
# vmin -0.18470943 vmax -0.18445817
# [VALID] epoch:  4 batch:  0 step:  20 loss:  0.4427577555179596 kl loss:  tensor(1.2775, device='mps:0')
# vmin -0.18465784 vmax -0.18454885
# [VALID] epoch:  4 batch:  0 step:  40 loss:  0.46105921268463135 kl loss:  tensor(1.2556, device='mps:0')
# vmin -0.1846609 vmax -0.18454589
# [VALID] epoch:  4 batch:  0 step:  60 loss:  0.4678977131843567 kl loss:  tensor(1.2854, device='mps:0')
# vmin -0.1846668 vmax -0.184548
# Epoch 5/1000, Train Loss: 4.486348e-01, Val Loss: 4.521042e-01
# [TRAIN] epoch:  5 batch:  0 step:  50 loss:  0.44920408725738525 recon_detail loss:  tensor(0.6728, device='mps:0') kl loss:  tensor(0.7670, device='mps:0')
# vmin -0.18470362 vmax -0.18455504
# [TRAIN] epoch:  5 batch:  1 step:  100 loss:  0.43897491693496704 recon_detail loss:  tensor(0.6382, device='mps:0') kl loss:  tensor(0.9438, device='mps:0')
# vmin -0.18419738 vmax -0.18372266
# [TRAIN] epoch:  5 batch:  2 step:  150 loss:  0.4507787823677063 recon_detail loss:  tensor(0.6497, device='mps:0') kl loss:  tensor(1.0123, device='mps:0')
# vmin -0.18561204 vmax -0.18465535
# [TRAIN] epoch:  5 batch:  3 step:  200 loss:  0.4521350860595703 recon_detail loss:  tensor(0.6865, device='mps:0') kl loss:  tensor(0.6851, device='mps:0')
# vmin -0.18465933 vmax -0.18446538
# [TRAIN] epoch:  5 batch:  3 step:  250 loss:  0.45212188363075256 recon_detail loss:  tensor(0.6538, device='mps:0') kl loss:  tensor(0.9905, device='mps:0')
# vmin -0.18465933 vmax -0.18446538
# [TRAIN] epoch:  5 batch:  4 step:  300 loss:  0.44581353664398193 recon_detail loss:  tensor(0.6518, device='mps:0') kl loss:  tensor(0.9233, device='mps:0')
# vmin -0.18470661 vmax -0.18461305
# [TRAIN] epoch:  5 batch:  5 step:  350 loss:  0.46411579847335815 recon_detail loss:  tensor(0.6713, device='mps:0') kl loss:  tensor(1.0265, device='mps:0')
# vmin -0.18478169 vmax -0.18386185
# [VALID] epoch:  5 batch:  0 step:  20 loss:  0.4626467823982239 kl loss:  tensor(0.9494, device='mps:0')
# vmin -0.18464683 vmax -0.18456271
# [VALID] epoch:  5 batch:  0 step:  40 loss:  0.4587443172931671 kl loss:  tensor(0.9453, device='mps:0')
# vmin -0.1846427 vmax -0.18456791
# [VALID] epoch:  5 batch:  0 step:  60 loss:  0.4786618649959564 kl loss:  tensor(0.9196, device='mps:0')
# vmin -0.18463898 vmax -0.18457314
# Epoch 6/1000, Train Loss: 4.542944e-01, Val Loss: 4.585778e-01
# [TRAIN] epoch:  6 batch:  0 step:  50 loss:  0.4435965418815613 recon_detail loss:  tensor(0.6806, device='mps:0') kl loss:  tensor(0.5807, device='mps:0')
# vmin -0.18557537 vmax -0.18468547
# [TRAIN] epoch:  6 batch:  1 step:  100 loss:  0.4666805565357208 recon_detail loss:  tensor(0.7239, device='mps:0') kl loss:  tensor(0.5704, device='mps:0')
# vmin -0.18555713 vmax -0.18358544
# [TRAIN] epoch:  6 batch:  2 step:  150 loss:  0.4691619873046875 recon_detail loss:  tensor(0.7320, device='mps:0') kl loss:  tensor(0.5176, device='mps:0')
# vmin -0.20597588 vmax -0.1622512
# [TRAIN] epoch:  6 batch:  3 step:  200 loss:  0.457538902759552 recon_detail loss:  tensor(0.6891, device='mps:0') kl loss:  tensor(0.7227, device='mps:0')
# vmin -0.18520923 vmax -0.18400724
# [TRAIN] epoch:  6 batch:  3 step:  250 loss:  0.44710999727249146 recon_detail loss:  tensor(0.6838, device='mps:0') kl loss:  tensor(0.6086, device='mps:0')
# vmin -0.1850297 vmax -0.18416041
# [TRAIN] epoch:  6 batch:  4 step:  300 loss:  0.4491584599018097 recon_detail loss:  tensor(0.7001, device='mps:0') kl loss:  tensor(0.5275, device='mps:0')
# vmin -0.18463764 vmax -0.18455432
# [TRAIN] epoch:  6 batch:  5 step:  350 loss:  0.4405067563056946 recon_detail loss:  tensor(0.7027, device='mps:0') kl loss:  tensor(0.3771, device='mps:0')
# vmin -0.18475641 vmax -0.18445803
# [VALID] epoch:  6 batch:  0 step:  20 loss:  0.4547100067138672 kl loss:  tensor(0.3801, device='mps:0')
# vmin -0.18464202 vmax -0.18457794
# [VALID] epoch:  6 batch:  0 step:  40 loss:  0.4658946990966797 kl loss:  tensor(0.3824, device='mps:0')
# vmin -0.18464936 vmax -0.18455409
# [VALID] epoch:  6 batch:  0 step:  60 loss:  0.44541701674461365 kl loss:  tensor(0.3859, device='mps:0')
# vmin -0.1846668 vmax -0.18455026
# Epoch 7/1000, Train Loss: 4.528436e-01, Val Loss: 4.551908e-01
# [TRAIN] epoch:  7 batch:  0 step:  50 loss:  0.4472256600856781 recon_detail loss:  tensor(0.7032, device='mps:0') kl loss:  tensor(0.4634, device='mps:0')
# vmin -0.1858131 vmax -0.18308507
# [TRAIN] epoch:  7 batch:  1 step:  100 loss:  0.8656616806983948 recon_detail loss:  tensor(0.8155, device='mps:0') kl loss:  tensor(4.9025, device='mps:0')
# vmin -0.18523224 vmax -0.18416615
# [TRAIN] epoch:  7 batch:  2 step:  150 loss:  0.5030661225318909 recon_detail loss:  tensor(0.8061, device='mps:0') kl loss:  tensor(0.4876, device='mps:0')
# vmin -0.18470687 vmax -0.18441004
# [TRAIN] epoch:  7 batch:  3 step:  200 loss:  0.48776349425315857 recon_detail loss:  tensor(0.8059, device='mps:0') kl loss:  tensor(0.2964, device='mps:0')
# vmin -0.18564977 vmax -0.18363494
# [TRAIN] epoch:  7 batch:  3 step:  250 loss:  0.48401081562042236 recon_detail loss:  tensor(0.8050, device='mps:0') kl loss:  tensor(0.2423, device='mps:0')
# vmin -0.18564968 vmax -0.18362702
# [TRAIN] epoch:  7 batch:  4 step:  300 loss:  0.4753604829311371 recon_detail loss:  tensor(0.7923, device='mps:0') kl loss:  tensor(0.2285, device='mps:0')
# vmin -0.1847951 vmax -0.18444368
# [TRAIN] epoch:  7 batch:  5 step:  350 loss:  0.4776695668697357 recon_detail loss:  tensor(0.7986, device='mps:0') kl loss:  tensor(0.2039, device='mps:0')
# vmin -0.18462539 vmax -0.18456675
# [VALID] epoch:  7 batch:  0 step:  20 loss:  0.473816454410553 kl loss:  tensor(0.1764, device='mps:0')
# vmin -0.18464738 vmax -0.18458019
# [VALID] epoch:  7 batch:  0 step:  40 loss:  0.47645899653434753 kl loss:  tensor(0.1737, device='mps:0')
# vmin -0.18464738 vmax -0.18458019
# [VALID] epoch:  7 batch:  0 step:  60 loss:  0.4747945964336395 kl loss:  tensor(0.1749, device='mps:0')
# vmin -0.18463953 vmax -0.184577
# Epoch 8/1000, Train Loss: 2.574910e+02, Val Loss: 4.743434e-01
# [TRAIN] epoch:  8 batch:  0 step:  50 loss:  0.46496424078941345 recon_detail loss:  tensor(0.7871, device='mps:0') kl loss:  tensor(0.1648, device='mps:0')
# vmin -0.1847402 vmax -0.18450528
# [TRAIN] epoch:  8 batch:  1 step:  100 loss:  0.4640224277973175 recon_detail loss:  tensor(0.7896, device='mps:0') kl loss:  tensor(0.1413, device='mps:0')
# vmin -0.18478832 vmax -0.18424742
# [TRAIN] epoch:  8 batch:  2 step:  150 loss:  0.4597812592983246 recon_detail loss:  tensor(0.7828, device='mps:0') kl loss:  tensor(0.1332, device='mps:0')
# vmin -0.18559016 vmax -0.18379752
# [TRAIN] epoch:  8 batch:  3 step:  200 loss:  0.46103790402412415 recon_detail loss:  tensor(0.7886, device='mps:0') kl loss:  tensor(0.1227, device='mps:0')
# vmin -0.18747346 vmax -0.18211678
# [TRAIN] epoch:  8 batch:  3 step:  250 loss:  0.4546564221382141 recon_detail loss:  tensor(0.7779, device='mps:0') kl loss:  tensor(0.1126, device='mps:0')
# vmin -0.18747346 vmax -0.18211678
# [TRAIN] epoch:  8 batch:  4 step:  300 loss:  0.46397167444229126 recon_detail loss:  tensor(0.7938, device='mps:0') kl loss:  tensor(0.1101, device='mps:0')
# vmin -0.18491311 vmax -0.1844498
# [TRAIN] epoch:  8 batch:  5 step:  350 loss:  0.46621081233024597 recon_detail loss:  tensor(0.7991, device='mps:0') kl loss:  tensor(0.0939, device='mps:0')
# vmin -0.18494782 vmax -0.18418834
# [VALID] epoch:  8 batch:  0 step:  20 loss:  0.4663586914539337 kl loss:  tensor(0.0948, device='mps:0')
# vmin -0.18464683 vmax -0.18456271
# [VALID] epoch:  8 batch:  0 step:  40 loss:  0.4670310318470001 kl loss:  tensor(0.0879, device='mps:0')
# vmin -0.18464461 vmax -0.18457964
# [VALID] epoch:  8 batch:  0 step:  60 loss:  0.4671526849269867 kl loss:  tensor(0.0925, device='mps:0')
# vmin -0.18464936 vmax -0.18455409
# Epoch 9/1000, Train Loss: 4.653393e-01, Val Loss: 4.656920e-01
# [TRAIN] epoch:  9 batch:  0 step:  50 loss:  0.45552143454551697 recon_detail loss:  tensor(0.7904, device='mps:0') kl loss:  tensor(0.0862, device='mps:0')
# vmin -0.18464288 vmax -0.18457226
# [TRAIN] epoch:  9 batch:  1 step:  100 loss:  0.4573691487312317 recon_detail loss:  tensor(0.7959, device='mps:0') kl loss:  tensor(0.0797, device='mps:0')
# vmin -0.1874106 vmax -0.1820551
# [TRAIN] epoch:  9 batch:  2 step:  150 loss:  0.45678308606147766 recon_detail loss:  tensor(0.7948, device='mps:0') kl loss:  tensor(0.0744, device='mps:0')
# vmin -0.18490073 vmax -0.18433508
# [TRAIN] epoch:  9 batch:  3 step:  200 loss:  0.4602087438106537 recon_detail loss:  tensor(0.8020, device='mps:0') kl loss:  tensor(0.0703, device='mps:0')
# vmin -0.18462276 vmax -0.18458004
# [TRAIN] epoch:  9 batch:  3 step:  250 loss:  0.4604809284210205 recon_detail loss:  tensor(0.8026, device='mps:0') kl loss:  tensor(0.0677, device='mps:0')
# vmin -0.18461865 vmax -0.1845791
# [TRAIN] epoch:  9 batch:  4 step:  300 loss:  0.45377036929130554 recon_detail loss:  tensor(0.7914, device='mps:0') kl loss:  tensor(0.0626, device='mps:0')
# vmin -0.18461742 vmax -0.18450314
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 276
#     273         json.dump(model_param, f, indent=2)
#     275 if __name__ == "__main__":
# --> 276     main()
#
# Cell In[1], line 249, in main()
#     247 loss_dict={}
#     248 for epoch in range(model_param['num_epochs']):
# --> 249     train_loss = train_one_epoch(model, train_loader, device, optimizer,model_param,epoch)
#     250     val_loss = eval_one_epoch(model, val_loader, device,model_param,epoch)
#     251     loss_dict[epoch] = {'train_loss':train_loss, 'val_loss':val_loss}
#
# Cell In[1], line 171, in train_one_epoch(model, loader, device, opt, model_param, epoch)
#     169 opt.zero_grad()
#     170 loss.backward()
# --> 171 opt.step()
#     172 total += float(loss.item())
#     173 count+=1
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/general/lib/python3.11/site-packages/torch/optim/optimizer.py:373, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     368         else:
#     369             raise RuntimeError(
#     370                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     371             )
# --> 373 out = func(*args, **kwargs)
#     374 self._optimizer_step_code()
#     376 # call optimizer step post hooks
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/general/lib/python3.11/site-packages/torch/optim/optimizer.py:76, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      74     torch.set_grad_enabled(self.defaults['differentiable'])
#      75     torch._dynamo.graph_break()
# ---> 76     ret = func(self, *args, **kwargs)
#      77 finally:
#      78     torch._dynamo.graph_break()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/general/lib/python3.11/site-packages/torch/optim/adam.py:163, in Adam.step(self, closure)
#     152     beta1, beta2 = group['betas']
#     154     self._init_group(
#     155         group,
#     156         params_with_grad,
#    (...)
#     160         max_exp_avg_sqs,
#     161         state_steps)
# --> 163     adam(
#     164         params_with_grad,
#     165         grads,
#     166         exp_avgs,
#     167         exp_avg_sqs,
#     168         max_exp_avg_sqs,
#     169         state_steps,
#     170         amsgrad=group['amsgrad'],
#     171         beta1=beta1,
#     172         beta2=beta2,
#     173         lr=group['lr'],
#     174         weight_decay=group['weight_decay'],
#     175         eps=group['eps'],
#     176         maximize=group['maximize'],
#     177         foreach=group['foreach'],
#     178         capturable=group['capturable'],
#     179         differentiable=group['differentiable'],
#     180         fused=group['fused'],
#     181         grad_scale=getattr(self, "grad_scale", None),
#     182         found_inf=getattr(self, "found_inf", None),
#     183     )
#     185 return loss
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/general/lib/python3.11/site-packages/torch/optim/adam.py:311, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     308 else:
#     309     func = _single_tensor_adam
# --> 311 func(params,
#     312      grads,
#     313      exp_avgs,
#     314      exp_avg_sqs,
#     315      max_exp_avg_sqs,
#     316      state_steps,
#     317      amsgrad=amsgrad,
#     318      beta1=beta1,
#     319      beta2=beta2,
#     320      lr=lr,
#     321      weight_decay=weight_decay,
#     322      eps=eps,
#     323      maximize=maximize,
#     324      capturable=capturable,
#     325      differentiable=differentiable,
#     326      grad_scale=grad_scale,
#     327      found_inf=found_inf)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/general/lib/python3.11/site-packages/torch/optim/adam.py:434, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     431     else:
#     432         denom = (exp_avg_sq.sqrt() / bias_correction2_sqrt).add_(eps)
# --> 434     param.addcdiv_(exp_avg, denom, value=-step_size)
#     436 # Lastly, switch back to complex view
#     437 if amsgrad and torch.is_complex(params[i]):
#
# KeyboardInterrupt:
